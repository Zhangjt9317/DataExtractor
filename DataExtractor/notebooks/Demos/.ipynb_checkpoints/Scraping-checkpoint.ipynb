# %% [markdown]
# # Scraping Documents From Websites
#
# ### Methods:
#
# Scientific articles used in this work are journal publications published by Springer, Wiley, Elsevier, the Royal Society of Chemistry, and the Electrochemical Society from which we received permissions to download large amount of articles. For each publisher, we manually identified all material science related journals available for download. A web scraping engine was built using scrapy. Only full-text articles publihsed after 2000 were downloaded, including metadata such as journal name, article title, article abstract, authors, etc.
#
# All data were stored in a document-oriented database implemented using a MongoDB database instance. Becasue downloaded articles are in HTML/XML format, which contains irrelevant markups and stylesheets, we developed a customized library for parsing article markup strings into text paragraphs while keeping the structures of paper and sections headings. The current snapshot of the database contains XXX papers, from which we used XXX paragraphs in the experimental sections of each paper to conduct this research. The experimental sections were identified by using case-insensitive keyword matching in section headings. keywords like "experiment", "synthesis", and their morphological derivations.

# %%
import pandas as pd
import re
import urllib
import time
import feedparser

import chemdataextractor
from chemdataextractor import Document
from chemdataextractor.reader import NlmXmlReader
from chemdataextractor.reader import XmlReader
from chemdataextractor.reader import PlainTextReader
import numpy as np
import requests

# %%
els_key = "4bc84cbdadca6050062348015ac963aa"
sn_key = "eca22bc7a0b1ee3153ab02c024a6a06e"
folder = "testing_download_articles/"

# %% [markdown]
# ## Search API
#
# In all platforms, we need to first search articles by topics of interst and then retrieve the full text using another API. Refer to https://dev.elsevier.com/documentation/FullTextRetrievalAPI.wadl

# %%
def arx_scrape(search_term, start_idx, scope='ti'):
    '''uses urllib, time, and feedparser'''
    #first escape search terms
    search_term= search_term.replace('"',"%22").replace(" ", "+");
    # set wait time and iteration step
    iterstep= 200;
    wait_time= 2 
    base_url = 'http://export.arxiv.org/api/query?'
    start= start_idx
    date_dict={
        "date":[],
        "article_id": [],
        "summary":[],
        "source": "arXiv"
    }
    
    while True:
        response= urllib.request.urlopen(els_base_url+f"search_query={scope}:{search_term}&sortBy=submittedDate&sortOrder=ascending&start={start}&max_results={iterstep}")
        feed= feedparser.parse(response)
        if not feed.entries:
            print('query complete')
            print(f"There should be {feed.feed.opensearch_totalresults} results?")
            break
        date_dict['date'].extend([entry.published for entry in feed.entries])
        date_dict['article_id'].extend([entry.id.split('/abs/')[-1] for entry in feed.entries])
        date_dict['summary'].extend([entry.summary.replace("\n", " ") for entry in feed.entries])
        print(f"gathering results {start} to {start + iterstep-1} ")
        start = start + iterstep
        time.sleep(wait_time)
        
    return pd.DataFrame(date_dict)

# %%
# #collect all all:organic photovoltaics from arXiv
# a1 = arx_scrape("all", 0, scope='organic photovoltaics OR organic solar cell')
# a2 = arx_scrape("all", 10000, scope='organic photovoltaics OR organic solar cell')
# a3 = arx_scrape("all", 12200, scope='organic photovoltaics OR organic solar cell')
# a4 = arx_scrape("all", 14400, scope='organic photovoltaics OR organic solar cell')

# %%
# all_a = pd.concat([a1, a2, a3, a4], ignore_index=True)
# all_a.head()
# all_a['date']= pd.DatetimeIndex(all_ai['date']).normalize()
# all_a.to_csv('./els.csv', index=False)

# %%
# a = pd.read_csv('./arxiv_physics.chem_ph.csv')
# corpus = a['summary']
# corpus = list(corpus)

# %%
# corpus

# %% [markdown]
# From the arXiv we have scraped 14800 abstracts,date and article ID for them. Usually abstracts contain the most concise information for the entire paper. Thus focusing on property extraction from abstracts is the main trend.
#
# The followings are elsvier and springer nature's api keys. In order to design a useful scraper, we beed to desgin multiple layers of filtering mechanism in order to scrape the right articles. For example, only "organic photovoltaics" or "peroskite solar cell" can also be broad. More details can be added to it.

# %% [markdown]
# ## Full Text Retrieval API
#
# This section use the full text retrieval API to retrieve full-article information and save it to either database (production) or local folders (development)

# %%
import requests

folder = "testing_download_articles"
# count is 10 so we output 10 results
els_url = "https://api.elsevier.com/content/search/scopus?query=organic%26photovoltaics&count=20&start=10&apiKey=4bc84cbdadca6050062348015ac963aa&year=2018"
r = requests.get(els_url)

with open(folder + '/write_test_els_paper2.json', 'wb') as file:
    file.write(r.content)

# %%
import json
from pprint import pprint
file = "testing_download_articles/write_test_els_paper2.json"

with open('testing_download_articles/write_test_els_paper2.json') as f:
    data = json.load(f)

pprint(data)
# Out:
# {'search-results': {'entry': [{'@_fa': 'true',
#                                'affiliation': [{'@_fa': 'true',
#                                                 'affiliation-city': 'Hangzhou',
#                                                 'affiliation-country': 'China',
#                                                 'affilname': 'Zhejiang '
#                                                              'Sci-Tech '
#                                                              'University'}],
#                                'article-number': '122813',
#                                'citedby-count': '0',
#                                'dc:creator': 'Pan J.',
#                                'dc:identifier': 'SCOPUS_ID:85072835274',
#                                'dc:title': 'The flexible-transparent p-n '
#                                            'junction film device of N-doped '
#                                            'Cu<inf>2</inf>O/SnO<inf>2</inf> '
#                                            'orderly nanowire arrays towards '
#                                            'highly photovoltaic conversion and '
#                                            'stability',
#                                'eid': '2-s2.0-85072835274',
#                                'link': [{'@_fa': 'true',
#                                          '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85072835274',
#                                          '@ref': 'self'},
#                                         {'@_fa': 'true',
#                                          '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85072835274?field=author,affiliation',
#                                          '@ref': 'author-affiliation'},
#                                         {'@_fa': 'true',
#                                          '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85072835274&origin=inward',
#                                          '@ref': 'scopus'},
#                                         {'@_fa': 'true',
#                                          '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85072835274&origin=inward',
#                                          '@ref': 'scopus-citedby'},
#                                         {'@_fa': 'true',
#                                          '@href': 'https://api.elsevier.com/content/article/eid/1-s2.0-S1385894719322235',
#                                          '@ref': 'full-text'}],
#                                'openaccess': '0',
#                                'openaccessFlag': False,
#                                'pii': 'S1385894719322235',
#                                'prism:aggregationType': 'Journal',
#                                'prism:coverDate': '2020-02-15',
#                                'prism:coverDisplayDate': '15 February 2020',
#                                'prism:doi': '10.1016/j.cej.2019.122813',
#                                'prism:issn': '13858947',
#                                'prism:pageRange': None,
#                                'prism:publicationName': 'Chemical Engineering '
#                                                         'Journal',
#                                'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85072835274',
#                                'prism:volume': '382',
#                                'source-id': '16398',
#                                'subtype': 'ar',
#                                'subtypeDescription': 'Article'},
#                               {'@_fa': 'true',
#                                'affiliation': [{'@_fa': 'true',
#                                                 'affiliation-city': 'Nanjing',
#                                                 'affiliation-country': 'China',
#                                                 'affilname': 'Nanjing '
#                                                              'University of '
#                                                              'Science and '
#                                                              'Technology'}],
#                                'article-number': '121260',
#                                'citedby-count': '0',
#                                'dc:creator': 'Zhang M.',
#                                'dc:identifier': 'SCOPUS_ID:85072785100',
#                                'dc:title': 'Improving the flame retardancy of '
#                                            'poly(lactic acid) using an '
#                                            'efficient ternary hybrid flame '
#                                            'retardant by dual modification of '
#                                            'graphene oxide with '
#                                            'phenylphosphinic acid and nano '
#                                            'MOFs',
#                                'eid': '2-s2.0-85072785100',
#                                'link': [{'@_fa': 'true',
#                                          '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85072785100',
#                                          '@ref': 'self'},
#                                         {'@_fa': 'true',
#                                          '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85072785100?field=author,affiliation',
#                                          '@ref': 'author-affiliation'},
#                                         {'@_fa': 'true',
#                                          '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85072785100&origin=inward',
#                                          '@ref': 'scopus'},
#                                         {'@_fa': 'true',
#                                          '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85072785100&origin=inward',
#                                          '@ref': 'scopus-citedby'},
#                                         {'@_fa': 'true',
#                                          '@href': 'https://api.elsevier.com/content/article/eid/1-s2.0-S0304389419312142',
#                                          '@ref': 'full-text'}],
#                                'openaccess': '0',
#                                'openaccessFlag': False,
#                                'pii': 'S0304389419312142',
#                                'prism:aggregationType': 'Journal',
#                                'prism:coverDate': '2020-02-15',
#                                'prism:coverDisplayDate': '15 February 2020',
#                                'prism:doi': '10.1016/j.jhazmat.2019.121260',
#                                'prism:eIssn': '18733336',
#                                'prism:issn': '03043894',
#                                'prism:pageRange': None,
#                                'prism:publicationName': 'Journal of Hazardous '
#                                                         'Materials',
#                                'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85072785100',
#                                'prism:volume': '384',
#                                'source-id': '25858',
#                                'subtype': 'ar',
#                                'subtypeDescription': 'Article'},
#                               {'@_fa': 'true',
#                                'affiliation': [{'@_fa': 'true',
#                                                 'affiliation-city': 'Changsha',
#                                                 'affiliation-country': 'China',
#                                                 'affilname': 'Hunan '
#                                                              'University'}],
#                                'article-number': '121275',
#                                'citedby-count': '0',
#                                'dc:creator': 'Chen Q.',
#                                'dc:identifier': 'SCOPUS_ID:85072764083',
#                                'dc:title': 'Enhanced visible light '
#                                            'photocatalytic activity of '
#                                            'g-C<inf>3</inf>N<inf>4</inf> '
#                                            'decorated ZrO<inf>2-x</inf> '
#                                            'nanotubes heterostructure for '
#                                            'degradation of tetracycline '
#                                            'hydrochloride',
#                                'eid': '2-s2.0-85072764083',
#                                'link': [{'@_fa': 'true',
#                                          '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85072764083',
#                                          '@ref': 'self'},
#                                         {'@_fa': 'true',
#                                          '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85072764083?field=author,affiliation',
#                                          '@ref': 'author-affiliation'},
#                                         {'@_fa': 'true',
#                                          '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85072764083&origin=inward',
#                                          '@ref': 'scopus'},
#                                         {'@_fa': 'true',
#                                          '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85072764083&origin=inward',
#                                          '@ref': 'scopus-citedby'},
#                                         {'@_fa': 'true',
#                                          '@href': 'https://api.elsevier.com/content/article/eid/1-s2.0-S0304389419312294',
#                                          '@ref': 'full-text'}],
#                                'openaccess': '0',
#                                'openaccessFlag': False,
#                                'pii': 'S0304389419312294',
#                                'prism:aggregationType': 'Journal',
#                                'prism:coverDate': '2020-02-15',
#                                'prism:coverDisplayDate': '15 February 2020',
#                                'prism:doi': '10.1016/j.jhazmat.2019.121275',
#                                'prism:eIssn': '18733336',
#                                'prism:issn': '03043894',
#                                'prism:pageRange': None,
#                                'prism:publicationName': 'Journal of Hazardous '
#                                                         'Materials',
#                                'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85072764083',
#                                'prism:volume': '384',
#                                'source-id': '25858',
#                                'subtype': 'ar',
#                                'subtypeDescription': 'Article'},
#                               {'@_fa': 'true',
#                                'affiliation': [{'@_fa': 'true',
#                                                 'affiliation-city': 'Nanjing',
#                                                 'affiliation-country': 'China',
#                                                 'affilname': 'Nanjing Forestry '
#                                                              'University'},
#                                                {'@_fa': 'true',
#                                                 'affiliation-city': 'Beijing',
#                                                 'affiliation-country': 'China',
#                                                 'affilname': 'Chinese Academy '
#                                                              'of Forestry'},
#                                                {'@_fa': 'true',
#                                                 'affiliation-city': 'Nanjing',
#                                                 'affiliation-country': 'China',
#                                                 'affilname': 'National '
#                                                              'Engineering Lab. '
#                                                              'for Biomass '
#                                                              'Chemical '
#                                                              'Utilization'},
#                                                {'@_fa': 'true',
#                                                 'affiliation-city': 'Nanjing',
#                                                 'affiliation-country': 'China',
#                                                 'affilname': 'Key Laboratory '
#                                                              'of Biomass '
#                                                              'Energy and '
#                                                              'Material'},
#                                                {'@_fa': 'true',
#                                                 'affiliation-city': 'Nanjing',
#                                                 'affiliation-country': 'China',
#                                                 'affilname': 'SFA'}],
#                                'article-number': '122464',
#                                'citedby-count': '0',
#                                'dc:creator': 'Wang F.',
#                                'dc:identifier': 'SCOPUS_ID:85072834363',
#                                'dc:title': 'Nitrogen-rich carbon-supported '
#                                            'ultrafine MoC nanoparticles for '
#                                            'the hydrotreatment of oleic acid '
#                                            'into diesel-like hydrocarbons',
#                                'eid': '2-s2.0-85072834363',
#                                'link': [{'@_fa': 'true',
#                                          '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85072834363',
#                                          '@ref': 'self'},
#                                         {'@_fa': 'true',
#                                          '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85072834363?field=author,affiliation',
#                                          '@ref': 'author-affiliation'},
#                                         {'@_fa': 'true',
#                                          '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85072834363&origin=inward',
#                                          '@ref': 'scopus'},
#                                         {'@_fa': 'true',
#                                          '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85072834363&origin=inward',
#                                          '@ref': 'scopus-citedby'},
#                                         {'@_fa': 'true',
#                                          '@href': 'https://api.elsevier.com/content/article/eid/1-s2.0-S1385894719318674',
#                                          '@ref': 'full-text'}],
#                                'openaccess': '0',
#                                'openaccessFlag': False,
#                                'pii': 'S1385894719318674',
#                                'prism:aggregationType': 'Journal',
#                                'prism:coverDate': '2020-02-15',
#                                'prism:coverDisplayDate': '15 February 2020',
#                                'prism:doi': '10.1016/j.cej.2019.122464',
#                                'prism:issn': '13858947',
#                                'prism:pageRange': None,
#                                'prism:publicationName': 'Chemical Engineering '
#                                                         'Journal',
#                                'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85072834363',
#                                'prism:volume': '382',
#                                'source-id': '16398',
#                                'subtype': 'ar',
#                                'subtypeDescription': 'Article'},
#                               {'@_fa': 'true',
#                                'affiliation': [{'@_fa': 'true',
#                                                 'affiliation-city': 'Mashhad',
#                                                 'affiliation-country': 'Iran',
#                                                 'affilname': 'Ferdowsi '
#                                                              'University of '
#                                                              'Mashhad'}],
#                                'article-number': '124780',
#                                'citedby-count': '0',
#                                'dc:creator': 'Kheybari S.',
#                                'dc:identifier': 'SCOPUS_ID:85072866001',
#                                'dc:title': 'Analytic network process: An '
#                                            'overview of applications',
#                                'eid': '2-s2.0-85072866001',
#                                'link': [{'@_fa': 'true',
#                                          '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85072866001',
#                                          '@ref': 'self'},
#                                         {'@_fa': 'true',
#                                          '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85072866001?field=author,affiliation',
#                                          '@ref': 'author-affiliation'},
#                                         {'@_fa': 'true',
#                                          '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85072866001&origin=inward',
#                                          '@ref': 'scopus'},
#                                         {'@_fa': 'true',
#                                          '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85072866001&origin=inward',
#                                          '@ref': 'scopus-citedby'},
#                                         {'@_fa': 'true',
#                                          '@href': 'https://api.elsevier.com/content/article/eid/1-s2.0-S0096300319307726',
#                                          '@ref': 'full-text'}],
#                                'openaccess': '0',
#                                'openaccessFlag': False,
#                                'pii': 'S0096300319307726',
#                                'prism:aggregationType': 'Journal',
#                                'prism:coverDate': '2020-02-15',
#                                'prism:coverDisplayDate': '15 February 2020',
#                                'prism:doi': '10.1016/j.amc.2019.124780',
#                                'prism:issn': '00963003',
#                                'prism:pageRange': None,
#                                'prism:publicationName': 'Applied Mathematics '
#                                                         'and Computation',
#                                'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85072866001',
#                                'prism:volume': '367',
#                                'source-id': '25170',
#                                'subtype': 'ar',
#                                'subtypeDescription': 'Article'},
#                               {'@_fa': 'true',
#                                'affiliation': [{'@_fa': 'true',
#                                                 'affiliation-city': 'Izmir',
#                                                 'affiliation-country': 'Turkey',
#                                                 'affilname': 'Izmir YÃ¼ksek '
#                                                              'Teknoloji '
#                                                              'EnstitÃ¼sÃ¼'},
#                                                {'@_fa': 'true',
#                                                 'affiliation-city': 'Urfa',
#                                                 'affiliation-country': 'Turkey',
#                                                 'affilname': 'Teknoma '
#                                                              'Technological '
#                                                              'Materials Ltd.'}],
#                                'citedby-count': '0',
#                                'dc:creator': 'Demirhan Y.',
#                                'dc:identifier': 'SCOPUS_ID:85069634762',
#                                'dc:title': 'The controllable deposÄ±tÄ±on of '
#                                            'large area roll-to-roll sputtered '
#                                            'ito thÄ±n fÄ±lms for photovoltaÄ±c '
#                                            'applÄ±catÄ±ons',
#                                'eid': '2-s2.0-85069634762',
#                                'link': [{'@_fa': 'true',
#                                          '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85069634762',
#                                          '@ref': 'self'},
#                                         {'@_fa': 'true',
#                                          '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85069634762?field=author,affiliation',
#                                          '@ref': 'author-affiliation'},
#                                         {'@_fa': 'true',
#                                          '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85069634762&origin=inward',
#                                          '@ref': 'scopus'},
#                                         {'@_fa': 'true',
#                                          '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85069634762&origin=inward',
#                                          '@ref': 'scopus-citedby'},
#                                         {'@_fa': 'true',
#                                          '@href': 'https://api.elsevier.com/content/article/eid/1-s2.0-S0960148119310584',
#                                          '@ref': 'full-text'}],
#                                'openaccess': '0',
#                                'openaccessFlag': False,
#                                'pii': 'S0960148119310584',
#                                'prism:aggregationType': 'Journal',
#                                'prism:coverDate': '2020-02-01',
#                                'prism:coverDisplayDate': 'February 2020',
#                                'prism:doi': '10.1016/j.renene.2019.07.038',
#                                'prism:eIssn': '18790682',
#                                'prism:issn': '09601481',
#                                'prism:pageRange': '1549-1559',
#                                'prism:publicationName': 'Renewable Energy',
#                                'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85069634762',
#                                'prism:volume': '146',
#                                'source-id': '27569',
#                                'subtype': 'ar',
#                                'subtypeDescription': 'Article'},
#                               {'@_fa': 'true',
#                                'affiliation': [{'@_fa': 'true',
#                                                 'affiliation-city': '3000 '
#                                                                     'Leuven',
#                                                 'affiliation-country': 'Belgium',
#                                                 'affilname': 'KU Leuven'}],
#                                'citedby-count': '0',
#                                'dc:creator': 'Ravyts S.',
#                                'dc:identifier': 'SCOPUS_ID:85068579290',
#                                'dc:title': 'Embedded BIPV module-level DC/DC '
#                                            'converters: Classification of '
#                                            'optimal ratings',
#                                'eid': '2-s2.0-85068579290',
#                                'link': [{'@_fa': 'true',
#                                          '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85068579290',
#                                          '@ref': 'self'},
#                                         {'@_fa': 'true',
#                                          '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85068579290?field=author,affiliation',
#                                          '@ref': 'author-affiliation'},
#                                         {'@_fa': 'true',
#                                          '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85068579290&origin=inward',
#                                          '@ref': 'scopus'},
#                                         {'@_fa': 'true',
#                                          '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85068579290&origin=inward',
#                                          '@ref': 'scopus-citedby'},
#                                         {'@_fa': 'true',
#                                          '@href': 'https://api.elsevier.com/content/article/eid/1-s2.0-S0960148119310389',
#                                          '@ref': 'full-text'}],
#                                'openaccess': '0',
#                                'openaccessFlag': False,
#                                'pii': 'S0960148119310389',
#                                'prism:aggregationType': 'Journal',
#                                'prism:coverDate': '2020-02-01',
#                                'prism:coverDisplayDate': 'February 2020',
#                                'prism:doi': '10.1016/j.renene.2019.07.018',
#                                'prism:eIssn': '18790682',
#                                'prism:issn': '09601481',
#                                'prism:pageRange': '880-889',
#                                'prism:publicationName': 'Renewable Energy',
#                                'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85068579290',
#                                'prism:volume': '146',
#                                'source-id': '27569',
#                                'subtype': 'ar',
#                                'subtypeDescription': 'Article'},
#                               {'@_fa': 'true',
#                                'affiliation': [{'@_fa': 'true',
#                                                 'affiliation-city': 'Busan',
#                                                 'affiliation-country': 'South '
#                                                                        'Korea',
#                                                 'affilname': 'Pukyong National '
#                                                              'University'}],
#                                'article-number': '107927',
#                                'citedby-count': '0',
#                                'dc:creator': 'Jeong M.',
#                                'dc:identifier': 'SCOPUS_ID:85072632638',
#                                'dc:title': 'Effect of interface modification '
#                                            'in polymer solar cells: An '
#                                            'in-depth investigation of the '
#                                            'structural variation of organic '
#                                            'dye for interlayer material',
#                                'eid': '2-s2.0-85072632638',
#                                'link': [{'@_fa': 'true',
#                                          '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85072632638',
#                                          '@ref': 'self'},
#                                         {'@_fa': 'true',
#                                          '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85072632638?field=author,affiliation',
#                                          '@ref': 'author-affiliation'},
#                                         {'@_fa': 'true',
#                                          '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85072632638&origin=inward',
#                                          '@ref': 'scopus'},
#                                         {'@_fa': 'true',
#                                          '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85072632638&origin=inward',
#                                          '@ref': 'scopus-citedby'},
#                                         {'@_fa': 'true',
#                                          '@href': 'https://api.elsevier.com/content/article/eid/1-s2.0-S0143720819318728',
#                                          '@ref': 'full-text'}],
#                                'openaccess': '0',
#                                'openaccessFlag': False,
#                                'pii': 'S0143720819318728',
#                                'prism:aggregationType': 'Journal',
#                                'prism:coverDate': '2020-02-01',
#                                'prism:coverDisplayDate': 'February 2020',
#                                'prism:doi': '10.1016/j.dyepig.2019.107927',
#                                'prism:eIssn': '18733743',
#                                'prism:issn': '01437208',
#                                'prism:pageRange': None,
#                                'prism:publicationName': 'Dyes and Pigments',
#                                'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85072632638',
#                                'prism:volume': '173',
#                                'source-id': '23502',
#                                'subtype': 'ar',
#                                'subtypeDescription': 'Article'},
#                               {'@_fa': 'true',
#                                'affiliation': [{'@_fa': 'true',
#                                                 'affiliation-city': 'Nanjing',
#                                                 'affiliation-country': 'China',
#                                                 'affilname': 'Nanjing '
#                                                              'University of '
#                                                              'Information '
#                                                              'Science and '
#                                                              'Technology'}],
#                                'article-number': '107925',
#                                'citedby-count': '0',
#                                'dc:creator': 'Xu K.',
#                                'dc:identifier': 'SCOPUS_ID:85072622868',
#                                'dc:title': 'Synergistic interactions between '
#                                            'N3 dye and perovskite '
#                                            'CH<inf>3</inf>NH<inf>3</inf>PbI<inf>3</inf> '
#                                            'for aqueous-based '
#                                            'photoresponsiveness under visible '
#                                            'light',
#                                'eid': '2-s2.0-85072622868',
#                                'link': [{'@_fa': 'true',
#                                          '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85072622868',
#                                          '@ref': 'self'},
#                                         {'@_fa': 'true',
#                                          '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85072622868?field=author,affiliation',
#                                          '@ref': 'author-affiliation'},
#                                         {'@_fa': 'true',
#                                          '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85072622868&origin=inward',
#                                          '@ref': 'scopus'},
#                                         {'@_fa': 'true',
#                                          '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85072622868&origin=inward',
#                                          '@ref': 'scopus-citedby'},
#                                         {'@_fa': 'true',
#                                          '@href': 'https://api.elsevier.com/content/article/eid/1-s2.0-S0143720819318753',
#                                          '@ref': 'full-text'}],
#                                'openaccess': '0',
#                                'openaccessFlag': False,
#                                'pii': 'S0143720819318753',
#                                'prism:aggregationType': 'Journal',
#                                'prism:coverDate': '2020-02-01',
#                                'prism:coverDisplayDate': 'February 2020',
#                                'prism:doi': '10.1016/j.dyepig.2019.107925',
#                                'prism:eIssn': '18733743',
#                                'prism:issn': '01437208',
#                                'prism:pageRange': None,
#                                'prism:publicationName': 'Dyes and Pigments',
#                                'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85072622868',
#                                'prism:volume': '173',
#                                'source-id': '23502',
#                                'subtype': 'ar',
#                                'subtypeDescription': 'Article'},
#                               {'@_fa': 'true',
#                                'affiliation': [{'@_fa': 'true',
#                                                 'affiliation-city': 'Quanzhou',
#                                                 'affiliation-country': 'China',
#                                                 'affilname': 'Huaqiao '
#                                                              'University'}],
#                                'citedby-count': '0',
#                                'dc:creator': 'Yu F.',
#                                'dc:identifier': 'SCOPUS_ID:85070819466',
#                                'dc:title': 'An explicit method to extract '
#                                            'fitting parameters in '
#                                            'lumped-parameter equivalent '
#                                            'circuit model of industrial solar '
#                                            'cells',
#                                'eid': '2-s2.0-85070819466',
#                                'link': [{'@_fa': 'true',
#                                          '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85070819466',
#                                          '@ref': 'self'},
#                                         {'@_fa': 'true',
#                                          '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85070819466?field=author,affiliation',
#                                          '@ref': 'author-affiliation'},
#                                         {'@_fa': 'true',
#                                          '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85070819466&origin=inward',
#                                          '@ref': 'scopus'},
#                                         {'@_fa': 'true',
#                                          '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85070819466&origin=inward',
#                                          '@ref': 'scopus-citedby'},
#                                         {'@_fa': 'true',
#                                          '@href': 'https://api.elsevier.com/content/article/eid/1-s2.0-S0960148119312571',
#                                          '@ref': 'full-text'}],
#                                'openaccess': '0',
#                                'openaccessFlag': False,
#                                'pii': 'S0960148119312571',
#                                'prism:aggregationType': 'Journal',
#                                'prism:coverDate': '2020-02-01',
#                                'prism:coverDisplayDate': 'February 2020',
#                                'prism:doi': '10.1016/j.renene.2019.08.070',
#                                'prism:eIssn': '18790682',
#                                'prism:issn': '09601481',
#                                'prism:pageRange': '2188-2198',
#                                'prism:publicationName': 'Renewable Energy',
#                                'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85070819466',
#                                'prism:volume': '146',
#                                'source-id': '27569',
#                                'subtype': 'ar',
#                                'subtypeDescription': 'Article'},
#                               {'@_fa': 'true',
#                                'affiliation': [{'@_fa': 'true',
#                                                 'affiliation-city': 'Dusseldorf',
#                                                 'affiliation-country': 'Germany',
#                                                 'affilname': 'Heinrich Heine '
#                                                              'UniversitÃ¤t'}],
#                                'article-number': '107890',
#                                'citedby-count': '0',
#                                'dc:creator': 'Niesobski P.',
#                                'dc:identifier': 'SCOPUS_ID:85072784594',
#                                'dc:title': 'A mild and sequentially '
#                                            'Pd/Cu-catalyzed domino synthesis '
#                                            'of acidochromic '
#                                            'Indolo[3,2-a]carbazoles â€“ Free '
#                                            'bases of apocyanine dyes',
#                                'eid': '2-s2.0-85072784594',
#                                'link': [{'@_fa': 'true',
#                                          '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85072784594',
#                                          '@ref': 'self'},
#                                         {'@_fa': 'true',
#                                          '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85072784594?field=author,affiliation',
#                                          '@ref': 'author-affiliation'},
#                                         {'@_fa': 'true',
#                                          '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85072784594&origin=inward',
#                                          '@ref': 'scopus'},
#                                         {'@_fa': 'true',
#                                          '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85072784594&origin=inward',
#                                          '@ref': 'scopus-citedby'},
#                                         {'@_fa': 'true',
#                                          '@href': 'https://api.elsevier.com/content/article/eid/1-s2.0-S0143720819313932',
#                                          '@ref': 'full-text'}],
#                                'openaccess': '0',
#                                'openaccessFlag': False,
#                                'pii': 'S0143720819313932',
#                                'prism:aggregationType': 'Journal',
#                                'prism:coverDate': '2020-02-01',
#                                'prism:coverDisplayDate': 'February 2020',
#                                'prism:doi': '10.1016/j.dyepig.2019.107890',
#                                'prism:eIssn': '18733743',
#                                'prism:issn': '01437208',
#                                'prism:pageRange': None,
#                                'prism:publicationName': 'Dyes and Pigments',
#                                'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85072784594',
#                                'prism:volume': '173',
#                                'source-id': '23502',
#                                'subtype': 'ar',
#                                'subtypeDescription': 'Article'},
#                               {'@_fa': 'true',
#                                'affiliation': [{'@_fa': 'true',
#                                                 'affiliation-city': 'Bengaluru',
#                                                 'affiliation-country': 'India',
#                                                 'affilname': 'Indian Institute '
#                                                              'of Science, '
#                                                              'Bengaluru'}],
#                                'article-number': '107887',
#                                'citedby-count': '0',
#                                'dc:creator': 'Gopi V.',
#                                'dc:identifier': 'SCOPUS_ID:85072285021',
#                                'dc:title': '2,3-di(2-furyl) quinoxaline '
#                                            'bearing 3 -ethyl rhodanine and 1,3 '
#                                            'indandione based heteroaromatic '
#                                            'conjugated T-shaped push -pull '
#                                            'chromophores: Design, synthesis, '
#                                            'photophysical and non-linear '
#                                            'optical investigations',
#                                'eid': '2-s2.0-85072285021',
#                                'link': [{'@_fa': 'true',
#                                          '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85072285021',
#                                          '@ref': 'self'},
#                                         {'@_fa': 'true',
#                                          '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85072285021?field=author,affiliation',
#                                          '@ref': 'author-affiliation'},
#                                         {'@_fa': 'true',
#                                          '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85072285021&origin=inward',
#                                          '@ref': 'scopus'},
#                                         {'@_fa': 'true',
#                                          '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85072285021&origin=inward',
#                                          '@ref': 'scopus-citedby'},
#                                         {'@_fa': 'true',
#                                          '@href': 'https://api.elsevier.com/content/article/eid/1-s2.0-S0143720819315244',
#                                          '@ref': 'full-text'}],
#                                'openaccess': '0',
#                                'openaccessFlag': False,
#                                'pii': 'S0143720819315244',
#                                'prism:aggregationType': 'Journal',
#                                'prism:coverDate': '2020-02-01',
#                                'prism:coverDisplayDate': 'February 2020',
#                                'prism:doi': '10.1016/j.dyepig.2019.107887',
#                                'prism:eIssn': '18733743',
#                                'prism:issn': '01437208',
#                                'prism:pageRange': None,
#                                'prism:publicationName': 'Dyes and Pigments',
#                                'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85072285021',
#                                'prism:volume': '173',
#                                'source-id': '23502',
#                                'subtype': 'ar',
#                                'subtypeDescription': 'Article'},
#                               {'@_fa': 'true',
#                                'affiliation': [{'@_fa': 'true',
#                                                 'affiliation-city': 'Chaing '
#                                                                     'Mai',
#                                                 'affiliation-country': 'Thailand',
#                                                 'affilname': 'Maejo '
#                                                              'University'}],
#                                'citedby-count': '0',
#                                'dc:creator': 'Chaiyat N.',
#                                'dc:identifier': 'SCOPUS_ID:85068507377',
#                                'dc:title': 'Levelized energy and exergy '
#                                            'costings per life cycle assessment '
#                                            'of a combined cooling, heating, '
#                                            'power and tourism system of the '
#                                            'San Kamphaeng hot spring, Thailand',
#                                'eid': '2-s2.0-85068507377',
#                                'link': [{'@_fa': 'true',
#                                          '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85068507377',
#                                          '@ref': 'self'},
#                                         {'@_fa': 'true',
#                                          '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85068507377?field=author,affiliation',
#                                          '@ref': 'author-affiliation'},
#                                         {'@_fa': 'true',
#                                          '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85068507377&origin=inward',
#                                          '@ref': 'scopus'},
#                                         {'@_fa': 'true',
#                                          '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85068507377&origin=inward',
#                                          '@ref': 'scopus-citedby'},
#                                         {'@_fa': 'true',
#                                          '@href': 'https://api.elsevier.com/content/article/eid/1-s2.0-S0960148119310481',
#                                          '@ref': 'full-text'}],
#                                'openaccess': '0',
#                                'openaccessFlag': False,
#                                'pii': 'S0960148119310481',
#                                'prism:aggregationType': 'Journal',
#                                'prism:coverDate': '2020-02-01',
#                                'prism:coverDisplayDate': 'February 2020',
#                                'prism:doi': '10.1016/j.renene.2019.07.028',
#                                'prism:eIssn': '18790682',
#                                'prism:issn': '09601481',
#                                'prism:pageRange': '828-842',
#                                'prism:publicationName': 'Renewable Energy',
#                                'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85068507377',
#                                'prism:volume': '146',
#                                'source-id': '27569',
#                                'subtype': 'ar',
#                                'subtypeDescription': 'Article'},
#                               {'@_fa': 'true',
#                                'affiliation': [{'@_fa': 'true',
#                                                 'affiliation-city': 'Hangzhou',
#                                                 'affiliation-country': 'China',
#                                                 'affilname': 'Zhejiang '
#                                                              'Sci-Tech '
#                                                              'University'}],
#                                'article-number': '107891',
#                                'citedby-count': '0',
#                                'dc:creator': 'Hu Q.',
# ...
#                                                 'affiliation-country': 'China',
#                                                 'affilname': 'East China '
#                                                              'University of '
#                                                              'Science and '
#                                                              'Technology'}],
#                                'article-number': '107880',
#                                'citedby-count': '0',
#                                'dc:creator': 'He Y.',
#                                'dc:identifier': 'SCOPUS_ID:85072370070',
#                                'dc:title': 'A triarylamine-based fluorescent '
#                                            'covalent organic framework for '
#                                            'efficient detection and removal of '
#                                            'Mercury(II) ion',
#                                'eid': '2-s2.0-85072370070',
#                                'link': [{'@_fa': 'true',
#                                          '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85072370070',
#                                          '@ref': 'self'},
#                                         {'@_fa': 'true',
#                                          '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85072370070?field=author,affiliation',
#                                          '@ref': 'author-affiliation'},
#                                         {'@_fa': 'true',
#                                          '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85072370070&origin=inward',
#                                          '@ref': 'scopus'},
#                                         {'@_fa': 'true',
#                                          '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85072370070&origin=inward',
#                                          '@ref': 'scopus-citedby'},
#                                         {'@_fa': 'true',
#                                          '@href': 'https://api.elsevier.com/content/article/eid/1-s2.0-S0143720819315682',
#                                          '@ref': 'full-text'}],
#                                'openaccess': '0',
#                                'openaccessFlag': False,
#                                'pii': 'S0143720819315682',
#                                'prism:aggregationType': 'Journal',
#                                'prism:coverDate': '2020-02-01',
#                                'prism:coverDisplayDate': 'February 2020',
#                                'prism:doi': '10.1016/j.dyepig.2019.107880',
#                                'prism:eIssn': '18733743',
#                                'prism:issn': '01437208',
#                                'prism:pageRange': None,
#                                'prism:publicationName': 'Dyes and Pigments',
#                                'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85072370070',
#                                'prism:volume': '173',
#                                'source-id': '23502',
#                                'subtype': 'ar',
#                                'subtypeDescription': 'Article'},
#                               {'@_fa': 'true',
#                                'affiliation': [{'@_fa': 'true',
#                                                 'affiliation-city': 'Aalborg',
#                                                 'affiliation-country': 'Denmark',
#                                                 'affilname': 'Aalborg '
#                                                              'Universitet'}],
#                                'citedby-count': '0',
#                                'dc:creator': 'Ã˜stergaard P.',
#                                'dc:identifier': 'SCOPUS_ID:85071084531',
#                                'dc:title': 'Sustainable development using '
#                                            'renewable energy technology',
#                                'eid': '2-s2.0-85071084531',
#                                'link': [{'@_fa': 'true',
#                                          '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85071084531',
#                                          '@ref': 'self'},
#                                         {'@_fa': 'true',
#                                          '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85071084531?field=author,affiliation',
#                                          '@ref': 'author-affiliation'},
#                                         {'@_fa': 'true',
#                                          '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85071084531&origin=inward',
#                                          '@ref': 'scopus'},
#                                         {'@_fa': 'true',
#                                          '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85071084531&origin=inward',
#                                          '@ref': 'scopus-citedby'},
#                                         {'@_fa': 'true',
#                                          '@href': 'https://api.elsevier.com/content/article/eid/1-s2.0-S0960148119312819',
#                                          '@ref': 'full-text'}],
#                                'openaccess': '0',
#                                'openaccessFlag': False,
#                                'pii': 'S0960148119312819',
#                                'prism:aggregationType': 'Journal',
#                                'prism:coverDate': '2020-02-01',
#                                'prism:coverDisplayDate': 'February 2020',
#                                'prism:doi': '10.1016/j.renene.2019.08.094',
#                                'prism:eIssn': '18790682',
#                                'prism:issn': '09601481',
#                                'prism:pageRange': '2430-2437',
#                                'prism:publicationName': 'Renewable Energy',
#                                'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85071084531',
#                                'prism:volume': '146',
#                                'source-id': '27569',
#                                'subtype': 're',
#                                'subtypeDescription': 'Review'},
#                               {'@_fa': 'true',
#                                'affiliation': [{'@_fa': 'true',
#                                                 'affiliation-city': 'Shenyang',
#                                                 'affiliation-country': 'China',
#                                                 'affilname': 'Institute of '
#                                                              'Metal Research '
#                                                              'Chinese Academy '
#                                                              'of Sciences'},
#                                                {'@_fa': 'true',
#                                                 'affiliation-city': 'Shenyang',
#                                                 'affiliation-country': 'China',
#                                                 'affilname': 'Shenyang '
#                                                              'University of '
#                                                              'Chemical '
#                                                              'Technology'}],
#                                'article-number': '107921',
#                                'citedby-count': '0',
#                                'dc:creator': 'Liu Y.',
#                                'dc:identifier': 'SCOPUS_ID:85072515004',
#                                'dc:title': 'Novel triphenylamine '
#                                            'polyazomethines bearing carbazole '
#                                            'and trifluoromethyl substituents: '
#                                            'Preparation and electrochromic '
#                                            'behavior',
#                                'eid': '2-s2.0-85072515004',
#                                'link': [{'@_fa': 'true',
#                                          '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85072515004',
#                                          '@ref': 'self'},
#                                         {'@_fa': 'true',
#                                          '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85072515004?field=author,affiliation',
#                                          '@ref': 'author-affiliation'},
#                                         {'@_fa': 'true',
#                                          '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85072515004&origin=inward',
#                                          '@ref': 'scopus'},
#                                         {'@_fa': 'true',
#                                          '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85072515004&origin=inward',
#                                          '@ref': 'scopus-citedby'},
#                                         {'@_fa': 'true',
#                                          '@href': 'https://api.elsevier.com/content/article/eid/1-s2.0-S014372081931767X',
#                                          '@ref': 'full-text'}],
#                                'openaccess': '0',
#                                'openaccessFlag': False,
#                                'pii': 'S014372081931767X',
#                                'prism:aggregationType': 'Journal',
#                                'prism:coverDate': '2020-02-01',
#                                'prism:coverDisplayDate': 'February 2020',
#                                'prism:doi': '10.1016/j.dyepig.2019.107921',
#                                'prism:eIssn': '18733743',
#                                'prism:issn': '01437208',
#                                'prism:pageRange': None,
#                                'prism:publicationName': 'Dyes and Pigments',
#                                'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85072515004',
#                                'prism:volume': '173',
#                                'source-id': '23502',
#                                'subtype': 'ar',
#                                'subtypeDescription': 'Article'},
#                               {'@_fa': 'true',
#                                'affiliation': [{'@_fa': 'true',
#                                                 'affiliation-city': "Xi'an",
#                                                 'affiliation-country': 'China',
#                                                 'affilname': 'Shaanxi Normal '
#                                                              'University'}],
#                                'article-number': '107881',
#                                'citedby-count': '0',
#                                'dc:creator': 'Yang X.',
#                                'dc:identifier': 'SCOPUS_ID:85072171911',
#                                'dc:title': 'New pyrene-based butterfly-shaped '
#                                            'blue AIEgens: Synthesis, '
#                                            'structure, aggregation-induced '
#                                            'emission and their nondoped blue '
#                                            'OLEDs',
#                                'eid': '2-s2.0-85072171911',
#                                'link': [{'@_fa': 'true',
#                                          '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85072171911',
#                                          '@ref': 'self'},
#                                         {'@_fa': 'true',
#                                          '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85072171911?field=author,affiliation',
#                                          '@ref': 'author-affiliation'},
#                                         {'@_fa': 'true',
#                                          '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85072171911&origin=inward',
#                                          '@ref': 'scopus'},
#                                         {'@_fa': 'true',
#                                          '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85072171911&origin=inward',
#                                          '@ref': 'scopus-citedby'},
#                                         {'@_fa': 'true',
#                                          '@href': 'https://api.elsevier.com/content/article/eid/1-s2.0-S0143720819317188',
#                                          '@ref': 'full-text'}],
#                                'openaccess': '0',
#                                'openaccessFlag': False,
#                                'pii': 'S0143720819317188',
#                                'prism:aggregationType': 'Journal',
#                                'prism:coverDate': '2020-02-01',
#                                'prism:coverDisplayDate': 'February 2020',
#                                'prism:doi': '10.1016/j.dyepig.2019.107881',
#                                'prism:eIssn': '18733743',
#                                'prism:issn': '01437208',
#                                'prism:pageRange': None,
#                                'prism:publicationName': 'Dyes and Pigments',
#                                'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85072171911',
#                                'prism:volume': '173',
#                                'source-id': '23502',
#                                'subtype': 'ar',
#                                'subtypeDescription': 'Article'}],
#                     'link': [{'@_fa': 'true',
#                               '@href': 'https://api.elsevier.com/content/search/scopus?start=10&count=20&query=organic%26photovoltaics&apiKey=4bc84cbdadca6050062348015ac963aa&year=2018',
#                               '@ref': 'self',
#                               '@type': 'application/json'},
#                              {'@_fa': 'true',
#                               '@href': 'https://api.elsevier.com/content/search/scopus?start=0&count=20&query=organic%26photovoltaics&apiKey=4bc84cbdadca6050062348015ac963aa&year=2018',
#                               '@ref': 'first',
#                               '@type': 'application/json'},
#                              {'@_fa': 'true',
#                               '@href': 'https://api.elsevier.com/content/search/scopus?start=0&count=20&query=organic%26photovoltaics&apiKey=4bc84cbdadca6050062348015ac963aa&year=2018',
#                               '@ref': 'prev',
#                               '@type': 'application/json'},
#                              {'@_fa': 'true',
#                               '@href': 'https://api.elsevier.com/content/search/scopus?start=30&count=20&query=organic%26photovoltaics&apiKey=4bc84cbdadca6050062348015ac963aa&year=2018',
#                               '@ref': 'next',
#                               '@type': 'application/json'},
#                              {'@_fa': 'true',
#                               '@href': 'https://api.elsevier.com/content/search/scopus?start=4980&count=20&query=organic%26photovoltaics&apiKey=4bc84cbdadca6050062348015ac963aa&year=2018',
#                               '@ref': 'last',
#                               '@type': 'application/json'}],
#                     'opensearch:Query': {'@role': 'request',
#                                          '@searchTerms': 'organic&photovoltaics',
#                                          '@startPage': '10'},
#                     'opensearch:itemsPerPage': '20',
#                     'opensearch:startIndex': '10',
#                     'opensearch:totalResults': '154492'}}

# %%
ls = []
ls2 = []
for i in data['search-results']['entry']:
    # print(i)
    if 'prism:doi' in i:
        # print(i['prism:doi'])
        ls.append(i['prism:doi'])
        ls2.append(i['dc:title'])
print(ls)
print(ls2)
# Out:
# ['10.1016/j.cej.2019.122813', '10.1016/j.jhazmat.2019.121260', '10.1016/j.jhazmat.2019.121275', '10.1016/j.cej.2019.122464', '10.1016/j.amc.2019.124780', '10.1016/j.renene.2019.07.038', '10.1016/j.renene.2019.07.018', '10.1016/j.dyepig.2019.107927', '10.1016/j.dyepig.2019.107925', '10.1016/j.renene.2019.08.070', '10.1016/j.dyepig.2019.107890', '10.1016/j.dyepig.2019.107887', '10.1016/j.renene.2019.07.028', '10.1016/j.dyepig.2019.107891', '10.1016/j.jechem.2019.04.019', '10.1016/j.dyepig.2019.107840', '10.1016/j.dyepig.2019.107880', '10.1016/j.renene.2019.08.094', '10.1016/j.dyepig.2019.107921', '10.1016/j.dyepig.2019.107881']
# ['The flexible-transparent p-n junction film device of N-doped Cu<inf>2</inf>O/SnO<inf>2</inf> orderly nanowire arrays towards highly photovoltaic conversion and stability', 'Improving the flame retardancy of poly(lactic acid) using an efficient ternary hybrid flame retardant by dual modification of graphene oxide with phenylphosphinic acid and nano MOFs', 'Enhanced visible light photocatalytic activity of g-C<inf>3</inf>N<inf>4</inf> decorated ZrO<inf>2-x</inf> nanotubes heterostructure for degradation of tetracycline hydrochloride', 'Nitrogen-rich carbon-supported ultrafine MoC nanoparticles for the hydrotreatment of oleic acid into diesel-like hydrocarbons', 'Analytic network process: An overview of applications', 'The controllable deposÄ±tÄ±on of large area roll-to-roll sputtered ito thÄ±n fÄ±lms for photovoltaÄ±c applÄ±catÄ±ons', 'Embedded BIPV module-level DC/DC converters: Classification of optimal ratings', 'Effect of interface modification in polymer solar cells: An in-depth investigation of the structural variation of organic dye for interlayer material', 'Synergistic interactions between N3 dye and perovskite CH<inf>3</inf>NH<inf>3</inf>PbI<inf>3</inf> for aqueous-based photoresponsiveness under visible light', 'An explicit method to extract fitting parameters in lumped-parameter equivalent circuit model of industrial solar cells', 'A mild and sequentially Pd/Cu-catalyzed domino synthesis of acidochromic Indolo[3,2-a]carbazoles â€“ Free bases of apocyanine dyes', '2,3-di(2-furyl) quinoxaline bearing 3 -ethyl rhodanine and 1,3 indandione based heteroaromatic conjugated T-shaped push -pull chromophores: Design, synthesis, photophysical and non-linear optical investigations', 'Levelized energy and exergy costings per life cycle assessment of a combined cooling, heating, power and tourism system of the San Kamphaeng hot spring, Thailand', 'An insight into the effect of S,S-dioxided thiophene on the opto-physical/electro-chemical properties and light stability for indophenine derivatives', 'Improved perovskite solar cell efficiency by tuning the colloidal size and free ion concentration in precursor solution using formic acid additive', 'Blue-colored dyes featuring a diketopyrrolopyrrole spacer for translucent dye-sensitized solar cells', 'A triarylamine-based fluorescent covalent organic framework for efficient detection and removal of Mercury(II) ion', 'Sustainable development using renewable energy technology', 'Novel triphenylamine polyazomethines bearing carbazole and trifluoromethyl substituents: Preparation and electrochromic behavior', 'New pyrene-based butterfly-shaped blue AIEgens: Synthesis, structure, aggregation-induced emission and their nondoped blue OLEDs']

# %%
def search_articles(file):
    """
    This is the combination of search and full text retrieval API
    input : JSON file location
    
    """
    names = []
    dois = []
    
    # read json as dictionary in python
    with open(file) as f:
        data = json.load(f)
    
    for i in data['search-results']['entry']:
        if 'prism:doi' in i:
            dois.append(i['prism:doi'])
            names.append(i['dc:title'])
    return dois, names

# %%
file = "testing_download_articles/write_test_els_paper2.json"

search_articles(file)
# Out:
# (['10.1016/j.cej.2019.122813',
#   '10.1016/j.jhazmat.2019.121260',
#   '10.1016/j.jhazmat.2019.121275',
#   '10.1016/j.cej.2019.122464',
#   '10.1016/j.amc.2019.124780',
#   '10.1016/j.renene.2019.07.038',
#   '10.1016/j.renene.2019.07.018',
#   '10.1016/j.dyepig.2019.107927',
#   '10.1016/j.dyepig.2019.107925',
#   '10.1016/j.renene.2019.08.070',
#   '10.1016/j.dyepig.2019.107890',
#   '10.1016/j.dyepig.2019.107887',
#   '10.1016/j.renene.2019.07.028',
#   '10.1016/j.dyepig.2019.107891',
#   '10.1016/j.jechem.2019.04.019',
#   '10.1016/j.dyepig.2019.107840',
#   '10.1016/j.dyepig.2019.107880',
#   '10.1016/j.renene.2019.08.094',
#   '10.1016/j.dyepig.2019.107921',
#   '10.1016/j.dyepig.2019.107881'],
#  ['The flexible-transparent p-n junction film device of N-doped Cu<inf>2</inf>O/SnO<inf>2</inf> orderly nanowire arrays towards highly photovoltaic conversion and stability',
#   'Improving the flame retardancy of poly(lactic acid) using an efficient ternary hybrid flame retardant by dual modification of graphene oxide with phenylphosphinic acid and nano MOFs',
#   'Enhanced visible light photocatalytic activity of g-C<inf>3</inf>N<inf>4</inf> decorated ZrO<inf>2-x</inf> nanotubes heterostructure for degradation of tetracycline hydrochloride',
#   'Nitrogen-rich carbon-supported ultrafine MoC nanoparticles for the hydrotreatment of oleic acid into diesel-like hydrocarbons',
#   'Analytic network process: An overview of applications',
#   'The controllable deposÄ±tÄ±on of large area roll-to-roll sputtered ito thÄ±n fÄ±lms for photovoltaÄ±c applÄ±catÄ±ons',
#   'Embedded BIPV module-level DC/DC converters: Classification of optimal ratings',
#   'Effect of interface modification in polymer solar cells: An in-depth investigation of the structural variation of organic dye for interlayer material',
#   'Synergistic interactions between N3 dye and perovskite CH<inf>3</inf>NH<inf>3</inf>PbI<inf>3</inf> for aqueous-based photoresponsiveness under visible light',
#   'An explicit method to extract fitting parameters in lumped-parameter equivalent circuit model of industrial solar cells',
#   'A mild and sequentially Pd/Cu-catalyzed domino synthesis of acidochromic Indolo[3,2-a]carbazoles â€“ Free bases of apocyanine dyes',
#   '2,3-di(2-furyl) quinoxaline bearing 3 -ethyl rhodanine and 1,3 indandione based heteroaromatic conjugated T-shaped push -pull chromophores: Design, synthesis, photophysical and non-linear optical investigations',
#   'Levelized energy and exergy costings per life cycle assessment of a combined cooling, heating, power and tourism system of the San Kamphaeng hot spring, Thailand',
#   'An insight into the effect of S,S-dioxided thiophene on the opto-physical/electro-chemical properties and light stability for indophenine derivatives',
#   'Improved perovskite solar cell efficiency by tuning the colloidal size and free ion concentration in precursor solution using formic acid additive',
#   'Blue-colored dyes featuring a diketopyrrolopyrrole spacer for translucent dye-sensitized solar cells',
#   'A triarylamine-based fluorescent covalent organic framework for efficient detection and removal of Mercury(II) ion',
#   'Sustainable development using renewable energy technology',
#   'Novel triphenylamine polyazomethines bearing carbazole and trifluoromethyl substituents: Preparation and electrochromic behavior',
#   'New pyrene-based butterfly-shaped blue AIEgens: Synthesis, structure, aggregation-induced emission and their nondoped blue OLEDs'])

# %% [markdown]
# ## Merge Them Together
#
# In this case we can combine both of them together to get a better view on

# %%
import requests

# %%
# pull articles
count = 0
for i in ls:
    els_url = 'https://api.elsevier.com/content/article/doi/' + i + '?APIKey=' + els_key
    r = requests.get(els_url)
    for num in range(len(ls)):
        with open(folder + f'/write_test_els_paper{num}.txt', 'wb') as file:
            file.write(r.content)

# %%
class search_and_pull:
    def __init__(self):
        self.els_key = "4bc84cbdadca6050062348015ac963aa"
        self.file = "testing_download_articles/write_test_els_paper2.json"
        self.folder = "testing_download_articles/"
        
    def search_articles(self,file):
        """
        This is the combination of search and full text retrieval API
        input : JSON file location
        """
        names = []
        dois = []

        # read json as dictionary in python
        file = self.file
        with open(file) as f:
            data = json.load(f)

        for i in data['search-results']['entry']:
            if 'prism:doi' in i:
                dois.append(i['prism:doi'])
                names.append(i['dc:title'])
        return dois

    def pull_articles(self,ls):
        """
        This function writes txt files for scraped documents
        """
        # pull articles
        doi = self.search_articles(file)
        els_key = self.els_key
        
        for i in doi:
            els_url = 'https://api.elsevier.com/content/article/doi/' + doi + '?APIKey=' + els_key
            r = requests.get(els_url)
            for num in range(len(ls)):
                with open(folder + f'/write_test_els_paper{num}.xml', 'wb') as file:
                    file.write(r.content)

# %%
els_url = 'https://api.elsevier.com/content/article/doi/10.1016/j.mattod.2014.07.007\
# ?APIKey=' + els_key

import requests
r = requests.get(els_url)
with open(folder + '/write_test_els_paperbb.html', 'wb') as file:
    file.write(r.content)
    
f = open('testing_download_articles/write_test_els_paperbb.html', 'rb')
doc = Document.from_file(f)

doc
# Out:
# <Document: 1940 elements>
