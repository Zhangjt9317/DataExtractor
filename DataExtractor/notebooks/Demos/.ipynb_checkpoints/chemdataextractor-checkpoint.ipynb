# %% [markdown]
# ## ChemDataExtractor (CDE) and Paper-parser (PP)
#
# environment setting:
# * use python version 2.7 - 3.6
# * all requirements are inside requirements.txt
# * use pipenv or conda to build virtual env
#
# The scientific abstracts used in this study are available via Elsiver's Scopus and Science Direct API's (https://dev.elsvier.com/), the Springer Nature API (https://dev.springernature.com/),the Royal Chemistry Society API. The list of DOIs used in this study, the pretrained model is built in chemdataextractor package, while extensive parsing rules and searching standards are done by the author.
#
# **Author:** Jingtian Zhang

# %% [markdown]
# ### Extracting a Custom Property

# %%
import chemdataextractor
import chemdataextractor.model as model
from chemdataextractor.model import Compound
from chemdataextractor.doc import Document, Heading, Paragraph, Sentence

# %% [markdown]
# ### Example Document
#
# Let's create a simple example document with a single heading followed by a single paragrah:

# %%
d = Document(
    Heading(u'Synthesis of 2,4,6-trinitrotoluene (3a)'),
    Paragraph(u'The procedure was followed to yield a pale yellow solid (b.p. 240 °C)')
)

# display a heading and a paragraph of the given content
d
# Out:
# <Document: 2 elements>

# %% [markdown]
# ### Default Parsers
#
# By default, chemdataextractor won't extract the boiling point property:

# %%
d.records.serialize()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-a47264c3a857> in <module>()
# ----> 1 d.records.serialize()
#
# ~/anaconda3/envs/MAT2env/lib/python3.5/site-packages/chemdataextractor/doc/document.py in records(self)
#     175             # Paragraph with single sentence with single ID record considered a head_def_record like heading
#     176             if isinstance(el, Paragraph) and len(el.sentences) == 1:
# --> 177                 el_records = el.records
#     178                 if len(el_records) == 1 and el_records[0].is_id_only:
#     179                     head_def_record = el_records[0]
#
# ~/anaconda3/envs/MAT2env/lib/python3.5/site-packages/chemdataextractor/doc/text.py in records(self)
#     231     def records(self):
#     232         """Return a list of records for this text passage."""
# --> 233         return ModelList(*[r for sent in self.sentences for r in sent.records])
#     234
#     235     def __add__(self, other):
#
# ~/anaconda3/envs/MAT2env/lib/python3.5/site-packages/chemdataextractor/doc/text.py in <listcomp>(.0)
#     231     def records(self):
#     232         """Return a list of records for this text passage."""
# --> 233         return ModelList(*[r for sent in self.sentences for r in sent.records])
#     234
#     235     def __add__(self, other):
#
# ~/anaconda3/envs/MAT2env/lib/python3.5/site-packages/chemdataextractor/doc/text.py in records(self)
#     510         tagged_tokens = [(CONTROL_RE.sub('', token), tag) for token, tag in self.tagged_tokens]
#     511         for parser in self.parsers:
# --> 512             for record in parser.parse(tagged_tokens):
#     513                 p = record.serialize()
#     514                 if not p:  # TODO: Potential performance issues?
#
# ~/anaconda3/envs/MAT2env/lib/python3.5/site-packages/chemdataextractor/parse/base.py in parse(self, tokens)
#      31     def parse(self, tokens):
#      32         for result in self.root.scan(tokens):
# ---> 33             for model in self.interpret(*result):
#      34                 yield model
#
# <ipython-input-21-6add4a831038> in interpret(self, result, start, end)
#       9             boiling_points=[
#      10                 BoilingPoint(
# ---> 11                     value=first(result.xpath('./value/text()')),
#      12                     units=first(result.xpath('./units/text()'))
#      13                 )
#
# AttributeError: 'list' object has no attribute 'xpath'

# %% [markdown]
# ### Defining a New Property Model
#
# The first task is to define the schema of a new property, and add it to the `Compound` model:

# %%
from chemdataextractor.model import BaseModel, StringType, ListType, ModelType

class BoilingPoint(BaseModel):
    value = StringType()
    units = StringType()
    
Compound.boiling_points = ListType(ModelType(BoilingPoint))

# %% [markdown]
# ### Then Writing a New Parser
#
# Next, define parsing rules that define how to interpret text and convert it into the model:

# %%
import re
from chemdataextractor.parse import R, I, W, Optional, merge

prefix = (R(u'^b\.?p\.?$', re.I) | I(u'boiling') + I(u'point')).hide()
units = (W(u'°') + Optional(R(u'^[CFK]\.?$')))(u'units').add_action(merge)
value = R(u'^\d+(\.\d+)?$')(u'value')
bp = (prefix + value + units)(u'bp')

# %%
from chemdataextractor.parse.base import BaseParser
from chemdataextractor.utils import first

class BpParser(BaseParser):
    root = bp

    def interpret(self, result, start, end):
        compound = Compound(
            boiling_points=[
                BoilingPoint(
                    value=first(result.xpath('./value/text()')),
                    units=first(result.xpath('./units/text()'))
                )
            ]
        )
        yield compound

# %%
Paragraph.parsers = [BpParser()]

# %% [markdown]
# ### Running the New Parser

# %%
d = Document(
    Heading(u'Synthesis of 2,4,6-trinitrotoluene (3a)'),
    Paragraph(u'The procedure was followed to yield a pale yellow solid (b.p. 240 °C)')
)

d.records.serialize()
# Out:
# [{'boiling_points': [{'units': '°C', 'value': '240'}],
#   'labels': ['3a'],
#   'names': ['2,4,6-trinitrotoluene'],
#   'roles': ['product']}]

# %% [markdown]
# ## Example from Documentation

# %%
doc = Document('UV-vis spectrum of 5,10,15,20-Tetra(4-carboxyphenyl)porphyrin in Tetrahydrofuran (THF).')
doc
# Out:
# <Document: 1 elements>

# %%
# each individual chemical entity mention (CEM)
doc.cems
# Out:
# [Span('Tetrahydrofuran', 65, 80),
#  Span('THF', 82, 85),
#  Span('5,10,15,20-Tetra(4-carboxyphenyl)porphyrin', 19, 61)]

# %%
doc.abbreviation_definitions
# Out:
# [(['THF'], ['Tetrahydrofuran'], 'CM')]

# %%
doc.records
doc.records[0].serialize()
doc.records[1].serialize()
# Out:
# {'names': ['Tetrahydrofuran', 'THF']}

# %% [markdown]
# ## Trying on OPV Documents
#
# we are going to extract some basic OPV optoelectronic properties from the documents. Here is the list of some fundamental properties:
#
# * Voc (V)
# * Jsc (mA cm-2)
# * FF (%)
# * PCE (%)
# * Bandgap, energy loss (Eloss), offsets (eV)
# * active area (cm2)
# * exposure time (s, min, hr, d)
# * Molecuar weight (Mw) (kg/mol)
# * hole and electron mobilities (cm2 V-1 s-1)
# * EQE, IQE (unitless)
# * absorption (nm)
#
# Since spectroscopy and other propertis can be automatically extracted, we are not going to focus too much on them.
#
# But we also want to extract AFM and TEM images from documents and their corresponding roughness and dump them into chemical database
#
# **Reading documents can break the doc into either paragraphs, and from paragraphs they can derive sentences or tokens**

# %% [markdown]
# While ChemDataExtractor supports documents in a wide variety of formats, some are better suited for extraction than others. If there is an HTML or XML version available, that is normally the best choice.
#
# Wherever possible, avoid using the PDF version of a paper or patent. At best, the text will be interpretable, but it is extremely difficult to reliably distinguish between headings, captions and main body text. At worst, the document will just consist of a scanned image of each page, and it won't be possible to extract any of the text at all. You can get some idea of what ChemDataExtractor can see in a PDF by looking at the result of copying-and-pasting from the document.
#
# For scientific articles, most publishers offer a HTML version alongside the PDF version. Normally, this will open as a page in your web browser. Just choose "Save As..." and ensure the selected format is "HTML" or "Page Source" to save a copy of the HTML file to your computer.
#
# Most patent offices provide XML versions of their patent documents, but these can be hard to find. Two useful resources are the USPTO Bulk Data Download Service and the EPO Open Patent Services API.
#
# **Reference**: http://www.chemdataextractor.org

# %%
f = open('example_doc.pdf', 'rb')
doc = Document.from_file(f)

# %%
doc.elements
doc.cems 
# the problem is author's name might be mistaken as a chemical name
# cems is returned as a `Span`, which contains the mention text, as well as 
# the start and end character offsets within the containing document element.
# Out:
# [Span('Li', 19, 21),
#  Span('Furan', 3747, 3752),
#  Span('PCBM', 104, 108),
#  Span('diketopyrrolopyrrole', 814, 834),
#  Span('alkyl', 36, 41),
#  Span('diketopyrrolopyrrole', 81, 101),
#  Span('H', 3658, 3659),
#  Span('thiophene', 0, 9),
#  Span('thiophene', 192, 201),
#  Span('thiophene', 256, 265),
#  Span('thiophene', 64, 73),
#  Span('pyrrole,24', 356, 366),
#  Span('S', 200, 201),
#  Span('Oh', 2457, 2459),
#  Span('Chalcogenophene', 1912, 1927),
#  Span('thiophene', 351, 360),
#  Span('Diketopyrrolopyrrole', 3312, 3332),
#  Span('selenophene-\nsubstituted', 920, 944),
#  Span('DPP', 730, 733),
#  Span('DPP', 618, 621),
#  Span('DPP', 1050, 1053),
#  Span('DPP', 10, 13),
#  Span('DPP', 83, 86),
#  Span('bithiophene,18 benzodithiophene', 423, 454),
#  Span('DPP', 234, 237),
#  Span('furan', 500, 505),
#  Span('4-methylthiophen-2-yl', 622, 643),
#  Span('phenyl', 977, 983),
#  Span('DPP', 836, 839),
#  Span('DPP', 324, 327),
#  Span('DPP', 0, 3),
#  Span('DPP', 920, 923),
#  Span('DPP', 340, 343),
#  Span('PBDTT', 63, 68),
#  Span('DPP', 110, 113),
#  Span('DPP', 784, 787),
#  Span('DPP', 909, 912),
#  Span('thiazole', 84, 92),
#  Span('Diketopyrrolopyrrole', 2532, 2552),
#  Span('Li', 40, 42),
#  Span('Li', 3215, 3217),
#  Span('Li', 2072, 2074),
#  Span('Anthopoulos', 2055, 2066),
#  Span('H', 1245, 1246),
#  Span('Li', 650, 652),
#  Span('H', 3208, 3209),
#  Span('selenophene\n(Se)24,34', 153, 174),
#  Span('DPP', 65, 68),
#  Span('diketopyrrolopyrrole', 1277, 1297),
#  Span('S', 1551, 1552),
#  Span('diketopyrrolopyrrole', 2900, 2920),
#  Span('diketopyrrolopyrrole', 1556, 1576),
#  Span('Thiophene', 241, 250),
#  Span('FETs.11,12', 529, 539),
#  Span('DPP', 29, 32),
#  Span('DPP', 61, 64),
#  Span('DPP', 381, 384),
#  Span('thiophene', 182, 191),
#  Span('[70]PCBM', 710, 718),
#  Span('Zinc Oxide', 998, 1008),
#  Span('DPP', 24, 27),
#  Span('Li', 2687, 2689),
#  Span('Diketopyrrolopyrrole', 3084, 3104),
#  Span('Li', 1721, 1723),
#  Span('DPP', 310, 313),
#  Span('Diketopyrrolopyrrole', 2901, 2921),
#  Span('Diketopyrrolopyrrole', 4044, 4064),
#  Span('selenophene-diketopyrrolopyrrole', 452, 484),
#  Span('Morin', 2161, 2166),
#  Span('DPP', 1943, 1946),
#  Span('DPP', 37, 40),
#  Span('DPP', 507, 510),
#  Span('Qxy', 187, 190),
#  Span('Li', 2846, 2848),
#  Span('diphenyl ether', 745, 759),
#  Span('thienothio-\nphene', 113, 130),
#  Span('amide', 4, 9),
#  Span('Selenium', 182, 190),
#  Span('DPP', 109, 112),
#  Span('thiophene', 373, 382),
#  Span('long\nbranched 2-decyltetradecyl alkyl', 967, 1004),
#  Span('Li', 838, 840),
#  Span('polymer F2-\nPDPP2TBP', 626, 646),
#  Span('carbazole', 539, 548),
#  Span('alkyl', 262, 267),
#  Span('H', 903, 904),
#  Span('Li', 1350, 1352),
#  Span('carbazole', 353, 362),
#  Span('benzodithiophene', 305, 321),
#  Span('H', 1532, 1533),
#  Span('Diketo-\npyrrolopyrrole', 2500, 2522),
#  Span('Li', 3692, 3694),
#  Span('H', 3081, 3082),
#  Span('PCBM', 337, 341),
#  Span('Oh', 196, 198),
#  Span('Diketopyrrolopyrrole', 433, 453),
#  Span('nitrogen', 1196, 1204),
#  Span('Diketopyrrolo-\npyrrole', 795, 817),
#  Span('palladium', 90, 99),
#  Span('chloroform', 898, 908),
#  Span('thienothiophene', 180, 195),
#  Span('Thieno[3,2-b]thiophene−Diketopyrrolo-\npyrrole', 2115, 2160),
#  Span('Ge', 1803, 1805),
#  Span('PDPPTPT', 102, 109),
#  Span('diketopyrrolopyrrole-terthiophene', 1380, 1413),
#  Span('bithiophene', 327, 338),
#  Span('O', 3487, 3488),
#  Span('Benzodithiophene', 4022, 4038),
#  Span('DPP', 69, 72),
#  Span('biphenyl', 422, 430),
#  Span('chlorobenzene', 718, 731),
#  Span('thiophene', 314, 323),
#  Span('DPP', 198, 201),
#  Span('DPP', 390, 393),
#  Span('[70]PCBM', 129, 137),
#  Span('DPP', 3494, 3497),
#  Span('biphenyl,23 phenyl,8 thiophene,8', 472, 504),
#  Span('PDPP2T-BT', 880, 889),
#  Span('pyridine', 151, 159),
#  Span('DPP', 4, 7),
#  Span('pyridine', 1208, 1216),
#  Span('fullerenes', 2003, 2013),
#  Span('[70]PCBM', 36, 44),
#  Span('PBTPyDPP\nPDPP3T\nPDPP2TT-Tc\nPMDPP3T\nPDPP2Tz-DTP\nPDPP2FT\nPBDTT', 18, 78),
#  Span('Li', 2859, 2861),
#  Span('DPP', 386, 389),
#  Span('ALKYL', 17, 22),
#  Span('DPP', 90, 93),
#  Span('Diketopyrrolopyrrole', 0, 20),
#  Span('PDPPTPT', 23, 30),
#  Span('alkyl', 54, 59),
#  Span('Alkylfuranyl-Substituted Benzo[1,2-b:4,5-b′]dithiophene', 1814, 1869),
#  Span('hydrogen', 833, 841),
#  Span('ﬂuorine', 585, 592),
#  Span('alkyl', 386, 391),
#  Span('selenophene', 599, 610),
#  Span('Tz', 94, 96),
#  Span('PCBM', 801, 805),
#  Span('alkyl', 75, 80),
#  Span('Logic', 1429, 1434),
#  Span('PCBM', 318, 322),
#  Span('S', 3235, 3236),
#  Span('phenyl', 855, 861),
#  Span('DPP', 830, 833),
#  Span('S', 3398, 3399),
#  Span('diketopyrrolopyrrole-bithio-\nphene-thienopyrrolodione', 2304, 2357),
#  Span('DPP', 215, 218),
#  Span('[70]PCBM', 110, 118),
#  Span('PDPP4T\nPDPP4TPD\nPDPP2T-TT\nPDPPTPyT\nPDPP3T\nPDPP2T-DTP\nPDPP2T-BT', 73, 135),
#  Span('Oligophenylenethiophenes', 1019, 1043),
#  Span('dithienylpyrrole,20', 483, 502),
#  Span('DPP', 283, 286),
#  Span('thiophene', 304, 313),
#  Span('(PDPP2T-\nDTP)24', 577, 592),
#  Span('Li', 1502, 1504),
#  Span('thiazole', 23, 31),
#  Span('hydrogen', 66, 74),
#  Span('DPP', 143, 146),
#  Span('thiophene', 241, 250),
#  Span('thiophen-2-yl', 4, 17),
#  Span('Li', 1430, 1432),
#  Span('dithienopyr', 981, 992),
#  Span('H', 2236, 2237),
#  Span('thiophene', 280, 289),
#  Span('diketopyrrolopyrrole', 975, 995),
#  Span('Diketopyrrolopyrrole', 3217, 3237),
#  Span('Fullerene', 121, 130),
#  Span('DPP', 31, 34),
#  Span('perovskite', 772, 782),
#  Span('Li', 3349, 3351),
#  Span('DPP', 842, 845),
#  Span('bi-\nphenyl', 1617, 1627),
#  Span('pyridine', 1261, 1269),
#  Span('thiazol-2-yl', 427, 439),
#  Span('selenophene', 1194, 1205),
#  Span('E242−E246', 849, 858),
#  Span('PFDPP2T\nPDPP2TBP\nPCBTDPP', 0, 24),
#  Span('DPP', 103, 106),
#  Span('PDPP', 9, 13),
#  Span('PDPP', 35, 39),
#  Span('PCBM', 516, 520),
#  Span('DPP', 615, 618),
#  Span('PCBM', 477, 481),
#  Span('Diketo-pyrrolo-pyrrole', 638, 660),
#  Span('thiophene', 23, 32),
#  Span('thiophene', 927, 936),
#  Span('2-octyldodecyl', 193, 207),
#  Span('DPP', 347, 350),
#  Span('DPP', 896, 899),
#  Span('DPP', 196, 199),
#  Span('DPP', 452, 455),
#  Span('thienopyrroledione (PDPP4TTPD)43', 707, 739),
#  Span('fullerene', 192, 201),
#  Span('thiophene', 820, 829),
#  Span('ﬂuorine', 743, 750),
#  Span('PCBM', 520, 524),
#  Span('PCBM.24', 1159, 1166),
#  Span('pyridine', 888, 896),
#  Span('thienothiophene', 268, 283),
#  Span('PCBM', 826, 830),
#  Span('Diketopyrrolopyrrole', 1630, 1650),
#  Span('Diketopyrrolopyrrole', 220, 240),
#  Span('Pellegrino', 168, 178),
#  Span('dithienopyrrole', 561, 576),
#  Span('Furan', 410, 415),
#  Span('P.-N', 817, 821),
#  Span('Li', 642, 644),
#  Span('H', 4030, 4031),
#  Span('alkyl', 1520, 1525),
#  Span('DPP', 945, 948),
#  Span('PCBM', 865, 869),
#  Span('fullerene', 477, 486),
#  Span('DPP', 509, 512),
#  Span('2-pyridyl.12', 999, 1011),
#  Span('biphenyl', 606, 614),
#  Span('ﬂuorene,44\nbiphenylene,23 carbazole,45 and naphthalene,46', 159, 216),
#  Span('thiophene', 226, 235),
#  Span('terthiophenes', 273, 286),
#  Span('alkyl-chain', 287, 298),
#  Span('S', 1462, 1463),
#  Span('carbazole-diketopyrrolopyrrole', 2751, 2781),
#  Span('O', 3671, 3672),
#  Span('aromatic nitrile', 162, 178),
#  Span('phenyl', 598, 604),
#  Span('π-\nconjugated aromatic', 404, 426),
#  Span('DPP', 263, 266),
#  Span('DPP', 949, 952),
#  Span('Phenyl', 343, 349),
#  Span('PBDTO', 25, 30),
#  Span('Anthopoulos', 408, 419),
#  Span('benzene', 339, 346),
#  Span('benzene', 259, 266),
#  Span('diketopyrrolopyrrole', 2550, 2570),
#  Span('DPP', 107, 110),
#  Span('benzodithiophene,40−42 bithiophene,40 thienothiophene[3,2-\nb],40', 287, 351),
#  Span('DPP', 419, 422),
#  Span('2-\nhexyldecyl', 170, 183),
#  Span('DPP', 227, 230),
#  Span('Li', 2640, 2642),
#  Span('DPP', 463, 466),
#  Span('−C\ue0c8\nN−', 236, 242),
#  Span('benzothiadiazole', 743, 759),
#  Span('PDPP2Tz-DTP', 574, 585),
#  Span('DPP', 76, 79),
#  Span('fullerene', 260, 269),
#  Span('α-carbon', 876, 884),
#  Span('DPP', 33, 36),
#  Span('DPP', 26, 29),
#  Span('S', 2832, 2833),
#  Span('Diketopyrrolopyrrole', 3538, 3558),
#  Span('Li', 2812, 2814),
#  Span('2-pyridyl', 1028, 1037),
#  Span('Parks', 548, 553),
#  Span('diketopyrrolopyrrole', 3252, 3272),
#  Span('thiophene', 19, 28),
#  Span('PCBM', 492, 496),
#  Span('Li', 3021, 3023),
#  Span('Diketopyrrolopyrrole', 55, 75),
#  Span('Li', 3977, 3979),
#  Span('thiophene', 808, 817),
#  Span('2-decyltetradecyl', 216, 233),
#  Span('DPP', 213, 216),
#  Span('thiophene', 460, 469),
#  Span('DPP', 709, 712),
#  Span('DPP', 149, 152),
#  Span('DPP', 22, 25),
#  Span('DPP', 278, 281),
#  Span('DPP', 70, 73),
#  Span('DPP', 38, 41),
#  Span('DPP', 1035, 1038),
#  Span('DPP', 395, 398),
#  Span('DPP', 518, 521),
#  Span('PDPP', 456, 460),
#  Span('fullerene', 410, 419),
#  Span('DPP', 1856, 1859),
#  Span('DPP', 540, 543),
#  Span('DPP', 44, 47),
#  Span('DPP', 1327, 1330),
#  Span('DPP', 1455, 1458),
#  Span('DPP', 112, 115),
#  Span('DPP', 12, 15),
#  Span('benzene', 10, 17),
#  Span('DPP', 368, 371),
#  Span('thienothiophene', 93, 108),
#  Span('Li', 179, 181),
#  Span('Diketopyrrolopyrrole', 992, 1012),
#  Span('PDPPTPT', 407, 414),
#  Span('Furan', 202, 207),
#  Span('Furan', 3530, 3535),
#  Span('oligothiophene', 142, 156),
#  Span('Li', 610, 612),
#  Span('diketo-pyrrolo-pyrrole', 1143, 1165),
#  Span('imine', 224, 229),
#  Span('Li', 882, 884),
#  Span('DPP', 208, 211),
#  Span('Diketopyrrolopyrrole', 1659, 1679),
#  Span('ﬂuorene', 367, 374),
#  Span('naphthalene', 265, 276),
#  Span('dibenzothio-\nphene', 285, 303),
#  Span('PBTPyDPP/PCBM', 1488, 1501),
#  Span('benzene', 1343, 1350),
#  Span('DPP', 245, 248),
#  Span('alkyl', 121, 126),
#  Span('Selenophene', 760, 771),
#  Span('DPP', 2705, 2708),
#  Span('Phenyl', 177, 183),
#  Span('alkyl', 27, 32)]

# %%
# element types include Title, Heading, Paragraph, Citation, Table, Figure, Caption and FootNode. 
# you can retrieve a specific element by its index within the document
para = doc.elements[3]
para
# Out:
# Paragraph(id=None, references=[], text='CONSPECTUS: Conjugated polymers have been extensively studied for\napplication in organic solar cells. In designing new polymers, particular\nattention has been given to tuning the absorption spectrum, molecular\nenergy levels, crystallinity, and charge carrier mobility to enhance\nperformance. As a result, the power conversion eﬃciencies (PCEs) of\nsolar cells based on conjugated polymers as electron donor and fullerene\nderivatives as electron acceptor have exceeded 10% in single-junction and\n11% in multijunction devices. Despite these eﬀorts, it is notoriously diﬃcult\nto establish thorough structure−property relationships that will be required\nto further optimize existing high-performance polymers to their intrinsic\nlimits.\nIn this Account, we highlight progress on the development and our\nunderstanding of diketopyrrolopyrrole (DPP) based conjugated polymers\nfor polymer solar cells. The DPP moiety is strongly electron withdrawing and its polar nature enhances the tendency of DPP-\nbased polymers to crystallize. As a result, DPP-based conjugated polymers often exhibit an advantageously broad and tunable\noptical absorption, up to 1000 nm, and high mobilities for holes and electrons, which can result in high photocurrents and good\nﬁll factors in solar cells. Here we focus on the structural modiﬁcations applied to DPP polymers and rationalize and explain the\nrelationships between chemical structure and organic photovoltaic performance. The DPP polymers can be tuned via their\naromatic substituents, their alkyl side chains, and the nature of the π-conjugated segment linking the units along the polymer\nchain. We show that these building blocks work together in determining the molecular conformation, the optical properties, the\ncharge carrier mobility, and the solubility of the polymer. We identify the latter as a decisive parameter for DPP-based organic\nsolar cells because it regulates the diameter of the semicrystalline DPP polymer ﬁbers that form in the photovoltaic blends with\nfullerenes via solution processing. The width of these ﬁbers and the photon energy loss, deﬁned as the energy diﬀerence between\noptical band gap and open-circuit voltage, together govern to a large extent the quantum eﬃciency for charge generation in these\nblends and thereby the power conversion eﬃciency of the photovoltaic devices. Lowering the photon energy loss and\nmaintaining a high quantum yield for charge generation is identiﬁed as a major pathway to enhance the performance of organic\nsolar cells. This can be achieved by controlling the structural purity of the materials and further control over morphology\nformation. We hope that this Account contributes to improved design strategies of DPP polymers that are required to realize new\nbreakthroughs in organic solar cell performance in the future.')

# %%
# you can get the individual sentences of a paragraph
para.sentences
# Out:
# [Sentence('CONSPECTUS: Conjugated polymers have been extensively studied for\napplication in organic solar cells.', 0, 101),
#  Sentence('In designing new polymers, particular\nattention has been given to tuning the absorption spectrum, molecular\nenergy levels, crystallinity, and charge carrier mobility to enhance\nperformance.', 102, 291),
#  Sentence('As a result, the power conversion eﬃciencies (PCEs) of\nsolar cells based on conjugated polymers as electron donor and fullerene\nderivatives as electron acceptor have exceeded 10% in single-junction and\n11% in multijunction devices.', 292, 523),
#  Sentence('Despite these eﬀorts, it is notoriously diﬃcult\nto establish thorough structure−property relationships that will be required\nto further optimize existing high-performance polymers to their intrinsic\nlimits.', 524, 730),
#  Sentence('In this Account, we highlight progress on the development and our\nunderstanding of diketopyrrolopyrrole (DPP) based conjugated polymers\nfor polymer solar cells.', 731, 891),
#  Sentence('The DPP moiety is strongly electron withdrawing and its polar nature enhances the tendency of DPP-\nbased polymers to crystallize.', 892, 1021),
#  Sentence('As a result, DPP-based conjugated polymers often exhibit an advantageously broad and tunable\noptical absorption, up to 1000 nm, and high mobilities for holes and electrons, which can result in high photocurrents and good\nﬁll factors in solar cells.', 1022, 1270),
#  Sentence('Here we focus on the structural modiﬁcations applied to DPP polymers and rationalize and explain the\nrelationships between chemical structure and organic photovoltaic performance.', 1271, 1450),
#  Sentence('The DPP polymers can be tuned via their\naromatic substituents, their alkyl side chains, and the nature of the π-conjugated segment linking the units along the polymer\nchain.', 1451, 1624),
#  Sentence('We show that these building blocks work together in determining the molecular conformation, the optical properties, the\ncharge carrier mobility, and the solubility of the polymer.', 1625, 1804),
#  Sentence('We identify the latter as a decisive parameter for DPP-based organic\nsolar cells because it regulates the diameter of the semicrystalline DPP polymer ﬁbers that form in the photovoltaic blends with\nfullerenes via solution processing.', 1805, 2038),
#  Sentence('The width of these ﬁbers and the photon energy loss, deﬁned as the energy diﬀerence between\noptical band gap and open-circuit voltage, together govern to a large extent the quantum eﬃciency for charge generation in these\nblends and thereby the power conversion eﬃciency of the photovoltaic devices.', 2039, 2337),
#  Sentence('Lowering the photon energy loss and\nmaintaining a high quantum yield for charge generation is identiﬁed as a major pathway to enhance the performance of organic\nsolar cells.', 2338, 2511),
#  Sentence('This can be achieved by controlling the structural purity of the materials and further control over morphology\nformation.', 2512, 2633),
#  Sentence('We hope that this Account contributes to improved design strategies of DPP polymers that are required to realize new\nbreakthroughs in organic solar cell performance in the future.', 2634, 2813)]

# %%
para.tokens
# Out:
# [[Token('CONSPECTUS', 0, 10),
#   Token(':', 10, 11),
#   Token('Conjugated', 12, 22),
#   Token('polymers', 23, 31),
#   Token('have', 32, 36),
#   Token('been', 37, 41),
#   Token('extensively', 42, 53),
#   Token('studied', 54, 61),
#   Token('for', 62, 65),
#   Token('application', 66, 77),
#   Token('in', 78, 80),
#   Token('organic', 81, 88),
#   Token('solar', 89, 94),
#   Token('cells', 95, 100),
#   Token('.', 100, 101)],
#  [Token('In', 102, 104),
#   Token('designing', 105, 114),
#   Token('new', 115, 118),
#   Token('polymers', 119, 127),
#   Token(',', 127, 128),
#   Token('particular', 129, 139),
#   Token('attention', 140, 149),
#   Token('has', 150, 153),
#   Token('been', 154, 158),
#   Token('given', 159, 164),
#   Token('to', 165, 167),
#   Token('tuning', 168, 174),
#   Token('the', 175, 178),
#   Token('absorption', 179, 189),
#   Token('spectrum', 190, 198),
#   Token(',', 198, 199),
#   Token('molecular', 200, 209),
#   Token('energy', 210, 216),
#   Token('levels', 217, 223),
#   Token(',', 223, 224),
#   Token('crystallinity', 225, 238),
#   Token(',', 238, 239),
#   Token('and', 240, 243),
#   Token('charge', 244, 250),
#   Token('carrier', 251, 258),
#   Token('mobility', 259, 267),
#   Token('to', 268, 270),
#   Token('enhance', 271, 278),
#   Token('performance', 279, 290),
#   Token('.', 290, 291)],
#  [Token('As', 292, 294),
#   Token('a', 295, 296),
#   Token('result', 297, 303),
#   Token(',', 303, 304),
#   Token('the', 305, 308),
#   Token('power', 309, 314),
#   Token('conversion', 315, 325),
#   Token('eﬃciencies', 326, 336),
#   Token('(', 337, 338),
#   Token('PCEs', 338, 342),
#   Token(')', 342, 343),
#   Token('of', 344, 346),
#   Token('solar', 347, 352),
#   Token('cells', 353, 358),
#   Token('based', 359, 364),
#   Token('on', 365, 367),
#   Token('conjugated', 368, 378),
#   Token('polymers', 379, 387),
#   Token('as', 388, 390),
#   Token('electron', 391, 399),
#   Token('donor', 400, 405),
#   Token('and', 406, 409),
#   Token('fullerene', 410, 419),
#   Token('derivatives', 420, 431),
#   Token('as', 432, 434),
#   Token('electron', 435, 443),
#   Token('acceptor', 444, 452),
#   Token('have', 453, 457),
#   Token('exceeded', 458, 466),
#   Token('10', 467, 469),
#   Token('%', 469, 470),
#   Token('in', 471, 473),
#   Token('single', 474, 480),
#   Token('-', 480, 481),
#   Token('junction', 481, 489),
#   Token('and', 490, 493),
#   Token('11', 494, 496),
#   Token('%', 496, 497),
#   Token('in', 498, 500),
#   Token('multijunction', 501, 514),
#   Token('devices', 515, 522),
#   Token('.', 522, 523)],
#  [Token('Despite', 524, 531),
#   Token('these', 532, 537),
#   Token('eﬀorts', 538, 544),
#   Token(',', 544, 545),
#   Token('it', 546, 548),
#   Token('is', 549, 551),
#   Token('notoriously', 552, 563),
#   Token('diﬃcult', 564, 571),
#   Token('to', 572, 574),
#   Token('establish', 575, 584),
#   Token('thorough', 585, 593),
#   Token('structure', 594, 603),
#   Token('−', 603, 604),
#   Token('property', 604, 612),
#   Token('relationships', 613, 626),
#   Token('that', 627, 631),
#   Token('will', 632, 636),
#   Token('be', 637, 639),
#   Token('required', 640, 648),
#   Token('to', 649, 651),
#   Token('further', 652, 659),
#   Token('optimize', 660, 668),
#   Token('existing', 669, 677),
#   Token('high', 678, 682),
#   Token('-', 682, 683),
#   Token('performance', 683, 694),
#   Token('polymers', 695, 703),
#   Token('to', 704, 706),
#   Token('their', 707, 712),
#   Token('intrinsic', 713, 722),
#   Token('limits', 723, 729),
#   Token('.', 729, 730)],
#  [Token('In', 731, 733),
#   Token('this', 734, 738),
#   Token('Account', 739, 746),
#   Token(',', 746, 747),
#   Token('we', 748, 750),
#   Token('highlight', 751, 760),
#   Token('progress', 761, 769),
#   Token('on', 770, 772),
#   Token('the', 773, 776),
#   Token('development', 777, 788),
#   Token('and', 789, 792),
#   Token('our', 793, 796),
#   Token('understanding', 797, 810),
#   Token('of', 811, 813),
#   Token('diketopyrrolopyrrole', 814, 834),
#   Token('(', 835, 836),
#   Token('DPP', 836, 839),
#   Token(')', 839, 840),
#   Token('based', 841, 846),
#   Token('conjugated', 847, 857),
#   Token('polymers', 858, 866),
#   Token('for', 867, 870),
#   Token('polymer', 871, 878),
#   Token('solar', 879, 884),
#   Token('cells', 885, 890),
#   Token('.', 890, 891)],
#  [Token('The', 892, 895),
#   Token('DPP', 896, 899),
#   Token('moiety', 900, 906),
#   Token('is', 907, 909),
#   Token('strongly', 910, 918),
#   Token('electron', 919, 927),
#   Token('withdrawing', 928, 939),
#   Token('and', 940, 943),
#   Token('its', 944, 947),
#   Token('polar', 948, 953),
#   Token('nature', 954, 960),
#   Token('enhances', 961, 969),
#   Token('the', 970, 973),
#   Token('tendency', 974, 982),
#   Token('of', 983, 985),
#   Token('DPP-', 986, 990),
#   Token('based', 991, 996),
#   Token('polymers', 997, 1005),
#   Token('to', 1006, 1008),
#   Token('crystallize', 1009, 1020),
#   Token('.', 1020, 1021)],
#  [Token('As', 1022, 1024),
#   Token('a', 1025, 1026),
#   Token('result', 1027, 1033),
#   Token(',', 1033, 1034),
#   Token('DPP', 1035, 1038),
#   Token('-', 1038, 1039),
#   Token('based', 1039, 1044),
#   Token('conjugated', 1045, 1055),
#   Token('polymers', 1056, 1064),
#   Token('often', 1065, 1070),
#   Token('exhibit', 1071, 1078),
#   Token('an', 1079, 1081),
#   Token('advantageously', 1082, 1096),
#   Token('broad', 1097, 1102),
#   Token('and', 1103, 1106),
#   Token('tunable', 1107, 1114),
#   Token('optical', 1115, 1122),
#   Token('absorption', 1123, 1133),
#   Token(',', 1133, 1134),
#   Token('up', 1135, 1137),
#   Token('to', 1138, 1140),
#   Token('1000', 1141, 1145),
#   Token('nm', 1146, 1148),
#   Token(',', 1148, 1149),
#   Token('and', 1150, 1153),
#   Token('high', 1154, 1158),
#   Token('mobilities', 1159, 1169),
#   Token('for', 1170, 1173),
#   Token('holes', 1174, 1179),
#   Token('and', 1180, 1183),
#   Token('electrons', 1184, 1193),
#   Token(',', 1193, 1194),
#   Token('which', 1195, 1200),
#   Token('can', 1201, 1204),
#   Token('result', 1205, 1211),
#   Token('in', 1212, 1214),
#   Token('high', 1215, 1219),
#   Token('photocurrents', 1220, 1233),
#   Token('and', 1234, 1237),
#   Token('good', 1238, 1242),
#   Token('ﬁll', 1243, 1246),
#   Token('factors', 1247, 1254),
#   Token('in', 1255, 1257),
#   Token('solar', 1258, 1263),
#   Token('cells', 1264, 1269),
#   Token('.', 1269, 1270)],
#  [Token('Here', 1271, 1275),
#   Token('we', 1276, 1278),
#   Token('focus', 1279, 1284),
#   Token('on', 1285, 1287),
#   Token('the', 1288, 1291),
#   Token('structural', 1292, 1302),
#   Token('modiﬁcations', 1303, 1315),
#   Token('applied', 1316, 1323),
#   Token('to', 1324, 1326),
#   Token('DPP', 1327, 1330),
#   Token('polymers', 1331, 1339),
#   Token('and', 1340, 1343),
#   Token('rationalize', 1344, 1355),
#   Token('and', 1356, 1359),
#   Token('explain', 1360, 1367),
#   Token('the', 1368, 1371),
#   Token('relationships', 1372, 1385),
#   Token('between', 1386, 1393),
#   Token('chemical', 1394, 1402),
#   Token('structure', 1403, 1412),
#   Token('and', 1413, 1416),
#   Token('organic', 1417, 1424),
#   Token('photovoltaic', 1425, 1437),
#   Token('performance', 1438, 1449),
#   Token('.', 1449, 1450)],
#  [Token('The', 1451, 1454),
#   Token('DPP', 1455, 1458),
#   Token('polymers', 1459, 1467),
#   Token('can', 1468, 1471),
#   Token('be', 1472, 1474),
#   Token('tuned', 1475, 1480),
#   Token('via', 1481, 1484),
#   Token('their', 1485, 1490),
#   Token('aromatic', 1491, 1499),
#   Token('substituents', 1500, 1512),
#   Token(',', 1512, 1513),
#   Token('their', 1514, 1519),
#   Token('alkyl', 1520, 1525),
#   Token('side', 1526, 1530),
#   Token('chains', 1531, 1537),
#   Token(',', 1537, 1538),
#   Token('and', 1539, 1542),
#   Token('the', 1543, 1546),
#   Token('nature', 1547, 1553),
#   Token('of', 1554, 1556),
#   Token('the', 1557, 1560),
#   Token('π-conjugated', 1561, 1573),
#   Token('segment', 1574, 1581),
#   Token('linking', 1582, 1589),
#   Token('the', 1590, 1593),
#   Token('units', 1594, 1599),
#   Token('along', 1600, 1605),
#   Token('the', 1606, 1609),
#   Token('polymer', 1610, 1617),
#   Token('chain', 1618, 1623),
#   Token('.', 1623, 1624)],
#  [Token('We', 1625, 1627),
#   Token('show', 1628, 1632),
#   Token('that', 1633, 1637),
#   Token('these', 1638, 1643),
#   Token('building', 1644, 1652),
#   Token('blocks', 1653, 1659),
#   Token('work', 1660, 1664),
#   Token('together', 1665, 1673),
#   Token('in', 1674, 1676),
#   Token('determining', 1677, 1688),
#   Token('the', 1689, 1692),
#   Token('molecular', 1693, 1702),
#   Token('conformation', 1703, 1715),
#   Token(',', 1715, 1716),
#   Token('the', 1717, 1720),
#   Token('optical', 1721, 1728),
#   Token('properties', 1729, 1739),
#   Token(',', 1739, 1740),
#   Token('the', 1741, 1744),
#   Token('charge', 1745, 1751),
#   Token('carrier', 1752, 1759),
#   Token('mobility', 1760, 1768),
#   Token(',', 1768, 1769),
#   Token('and', 1770, 1773),
#   Token('the', 1774, 1777),
#   Token('solubility', 1778, 1788),
#   Token('of', 1789, 1791),
#   Token('the', 1792, 1795),
#   Token('polymer', 1796, 1803),
#   Token('.', 1803, 1804)],
#  [Token('We', 1805, 1807),
#   Token('identify', 1808, 1816),
#   Token('the', 1817, 1820),
#   Token('latter', 1821, 1827),
#   Token('as', 1828, 1830),
#   Token('a', 1831, 1832),
#   Token('decisive', 1833, 1841),
#   Token('parameter', 1842, 1851),
#   Token('for', 1852, 1855),
#   Token('DPP', 1856, 1859),
#   Token('-', 1859, 1860),
#   Token('based', 1860, 1865),
#   Token('organic', 1866, 1873),
#   Token('solar', 1874, 1879),
#   Token('cells', 1880, 1885),
#   Token('because', 1886, 1893),
#   Token('it', 1894, 1896),
#   Token('regulates', 1897, 1906),
#   Token('the', 1907, 1910),
#   Token('diameter', 1911, 1919),
#   Token('of', 1920, 1922),
#   Token('the', 1923, 1926),
#   Token('semicrystalline', 1927, 1942),
#   Token('DPP', 1943, 1946),
#   Token('polymer', 1947, 1954),
#   Token('ﬁbers', 1955, 1960),
#   Token('that', 1961, 1965),
#   Token('form', 1966, 1970),
#   Token('in', 1971, 1973),
#   Token('the', 1974, 1977),
#   Token('photovoltaic', 1978, 1990),
#   Token('blends', 1991, 1997),
#   Token('with', 1998, 2002),
#   Token('fullerenes', 2003, 2013),
#   Token('via', 2014, 2017),
#   Token('solution', 2018, 2026),
#   Token('processing', 2027, 2037),
#   Token('.', 2037, 2038)],
#  [Token('The', 2039, 2042),
#   Token('width', 2043, 2048),
#   Token('of', 2049, 2051),
#   Token('these', 2052, 2057),
#   Token('ﬁbers', 2058, 2063),
#   Token('and', 2064, 2067),
#   Token('the', 2068, 2071),
#   Token('photon', 2072, 2078),
#   Token('energy', 2079, 2085),
#   Token('loss', 2086, 2090),
#   Token(',', 2090, 2091),
#   Token('deﬁned', 2092, 2098),
#   Token('as', 2099, 2101),
#   Token('the', 2102, 2105),
#   Token('energy', 2106, 2112),
#   Token('diﬀerence', 2113, 2122),
#   Token('between', 2123, 2130),
#   Token('optical', 2131, 2138),
#   Token('band', 2139, 2143),
#   Token('gap', 2144, 2147),
#   Token('and', 2148, 2151),
#   Token('open', 2152, 2156),
#   Token('-', 2156, 2157),
#   Token('circuit', 2157, 2164),
#   Token('voltage', 2165, 2172),
#   Token(',', 2172, 2173),
#   Token('together', 2174, 2182),
#   Token('govern', 2183, 2189),
#   Token('to', 2190, 2192),
#   Token('a', 2193, 2194),
#   Token('large', 2195, 2200),
#   Token('extent', 2201, 2207),
#   Token('the', 2208, 2211),
#   Token('quantum', 2212, 2219),
#   Token('eﬃciency', 2220, 2228),
#   Token('for', 2229, 2232),
#   Token('charge', 2233, 2239),
#   Token('generation', 2240, 2250),
#   Token('in', 2251, 2253),
#   Token('these', 2254, 2259),
#   Token('blends', 2260, 2266),
#   Token('and', 2267, 2270),
#   Token('thereby', 2271, 2278),
#   Token('the', 2279, 2282),
#   Token('power', 2283, 2288),
#   Token('conversion', 2289, 2299),
#   Token('eﬃciency', 2300, 2308),
#   Token('of', 2309, 2311),
#   Token('the', 2312, 2315),
#   Token('photovoltaic', 2316, 2328),
#   Token('devices', 2329, 2336),
#   Token('.', 2336, 2337)],
#  [Token('Lowering', 2338, 2346),
#   Token('the', 2347, 2350),
#   Token('photon', 2351, 2357),
#   Token('energy', 2358, 2364),
#   Token('loss', 2365, 2369),
#   Token('and', 2370, 2373),
#   Token('maintaining', 2374, 2385),
#   Token('a', 2386, 2387),
#   Token('high', 2388, 2392),
#   Token('quantum', 2393, 2400),
#   Token('yield', 2401, 2406),
#   Token('for', 2407, 2410),
#   Token('charge', 2411, 2417),
#   Token('generation', 2418, 2428),
#   Token('is', 2429, 2431),
#   Token('identiﬁed', 2432, 2441),
#   Token('as', 2442, 2444),
#   Token('a', 2445, 2446),
#   Token('major', 2447, 2452),
#   Token('pathway', 2453, 2460),
#   Token('to', 2461, 2463),
#   Token('enhance', 2464, 2471),
#   Token('the', 2472, 2475),
#   Token('performance', 2476, 2487),
#   Token('of', 2488, 2490),
#   Token('organic', 2491, 2498),
#   Token('solar', 2499, 2504),
#   Token('cells', 2505, 2510),
#   Token('.', 2510, 2511)],
#  [Token('This', 2512, 2516),
#   Token('can', 2517, 2520),
#   Token('be', 2521, 2523),
#   Token('achieved', 2524, 2532),
#   Token('by', 2533, 2535),
#   Token('controlling', 2536, 2547),
#   Token('the', 2548, 2551),
#   Token('structural', 2552, 2562),
#   Token('purity', 2563, 2569),
#   Token('of', 2570, 2572),
#   Token('the', 2573, 2576),
#   Token('materials', 2577, 2586),
#   Token('and', 2587, 2590),
#   Token('further', 2591, 2598),
#   Token('control', 2599, 2606),
#   Token('over', 2607, 2611),
#   Token('morphology', 2612, 2622),
#   Token('formation', 2623, 2632),
#   Token('.', 2632, 2633)],
#  [Token('We', 2634, 2636),
#   Token('hope', 2637, 2641),
#   Token('that', 2642, 2646),
#   Token('this', 2647, 2651),
#   Token('Account', 2652, 2659),
#   Token('contributes', 2660, 2671),
#   Token('to', 2672, 2674),
#   Token('improved', 2675, 2683),
#   Token('design', 2684, 2690),
#   Token('strategies', 2691, 2701),
#   Token('of', 2702, 2704),
#   Token('DPP', 2705, 2708),
#   Token('polymers', 2709, 2717),
#   Token('that', 2718, 2722),
#   Token('are', 2723, 2726),
#   Token('required', 2727, 2735),
#   Token('to', 2736, 2738),
#   Token('realize', 2739, 2746),
#   Token('new', 2747, 2750),
#   Token('breakthroughs', 2751, 2764),
#   Token('in', 2765, 2767),
#   Token('organic', 2768, 2775),
#   Token('solar', 2776, 2781),
#   Token('cell', 2782, 2786),
#   Token('performance', 2787, 2798),
#   Token('in', 2799, 2801),
#   Token('the', 2802, 2805),
#   Token('future', 2806, 2812),
#   Token('.', 2812, 2813)]]

# %% [markdown]
# ### Designing New Parsing Rules for Properties
#
# 1. defining a new property model
# 2. writing a new parser
# 3. running the new parser
#
# we can use functions described in chemdataextractor website
#
# ChemDataExtractor contains a chemistry-aware Part-of-speech tagger. Use the `pos_tagged_tokens` property on a document element to get the tagged tokens:

# %%
# use pos_tagged_tokens property on a document element to get the tagged tokens
s = Sentence('1H NMR spectra were recorded on a 300 MHz BRUKER DPX300 spectrometer.')
s.pos_tagged_tokens
# Out:
# [('1H', 'NN'),
#  ('NMR', 'NN'),
#  ('spectra', 'NNS'),
#  ('were', 'VBD'),
#  ('recorded', 'VBN'),
#  ('on', 'IN'),
#  ('a', 'DT'),
#  ('300', 'CD'),
#  ('MHz', 'NNP'),
#  ('BRUKER', 'NNP'),
#  ('DPX300', 'NNP'),
#  ('spectrometer', 'NN'),
#  ('.', '.')]

# %%
# using taggers directly
from chemdataextractor.nlp.pos import ChemCrfPosTagger
cpt = ChemCrfPosTagger()
cpt.tag(['1H', 'NMR', 'spectra', 'were', 'recorded', 'on', 'a', '300', 'MHz', 'BRUKER', 'DPX300', 'spectrometer', '.'])
# Out:
# [('1H', 'NN'),
#  ('NMR', 'NN'),
#  ('spectra', 'NNS'),
#  ('were', 'VBD'),
#  ('recorded', 'VBN'),
#  ('on', 'IN'),
#  ('a', 'DT'),
#  ('300', 'CD'),
#  ('MHz', 'NNP'),
#  ('BRUKER', 'NNP'),
#  ('DPX300', 'NNP'),
#  ('spectrometer', 'NN'),
#  ('.', '.')]

# %%
from chemdataextractor.model import BaseModel, StringType, ListType, ModelType

class Mobility(BaseModel):
    value = StringType()
    units = StringType()
class Voc(BaseModel):
    value = StringType()
    units = StringType()
class FF(BaseModel):
    value = StringType()
    units = StringType()
class PCE(BaseModel):
    value = StringType()
    units = StringType()
class Area(BaseModel):
    value = StringType()
    units = StringType()

Compound.Jsc = ListType(ModelType(Jsc))
Compound.Voc = ListType(ModelType(Voc))
Compound.FF = ListType(ModelType(FF))
Compound.PCE = ListType(ModelType(PCE))
Compound.Area = ListType(ModelType(Area))

# %%
import re
from chemdataextractor.parse import R, I, W, Optional, merge

prefix = (I(u'mobilities')).hide()
units = (W(u'cm2 V−1 s−1') + Optional(R(u'^[CFK]\.?$')))(u'units').add_action(merge)
value = R(u'^\d+(\.\d+)?$')(u'value')
mu = (prefix + units + value)(u'mu')

# %%
from chemdataextractor.parse.base import BaseParser
from chemdataextractor.utils import first

class muParser(BaseParser):
    root = mu

    def interpret(self, result, start, end):
        compound = Compound(
            mobility=[
                Mobility(
                    value=first(result.xpath('./value/text()')),
                    units=first(result.xpath('./units/text()'))
                )
            ]
        )
        yield compound

Paragraph.parsers = [muParser()]
d = Document(
    Paragraph(u'Thiophene-substituted DPP polymers show high hole and electron mobilities above 1 cm2 V−1 s−1 in FETs.16 By copolymerization of the thiophene-substituted DPP with π- conjugated aromatic monomers of different donor strength, such as biphenyl,23 phenyl,8 thiophene,8 and dithienopyrrole,24 the absorption onset can be tuned from 750 nm to above 1000 nm. The PCEs can reach 9.4%.')
)
d.records.serialize()
# Out:
# []

# %%
d = Document(
    Paragraph(u'Thiophene-substituted DPP polymers show high hole and electron mobilities above 1 cm2 V−1 s−1 in FETs.16 By copolymerization of the thiophene-substituted DPP with π- conjugated aromatic monomers of different donor strength, such as biphenyl,23 phenyl,8 thiophene,8 and dithienopyrrole,24 the absorption onset can be tuned from 750 nm to above 1000 nm. The PCEs can reach 9.4%.')
)
# we can see cems working fine
d.cems
# but d.records.serialize() doesn't return anything, only []
# Out:
# <bound method Sequence.count of <Document: 1 elements>>

# %% [markdown]
# ### As shown above and in the extracting_a_custom_property notebook, there is no
